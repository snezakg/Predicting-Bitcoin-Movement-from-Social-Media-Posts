# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sb
import matplotlib.colors as mcolors

import time
from datetime import datetime, timedelta

from sklearn.model_selection import train_test_split
import xgboost as xgb

# Metrics
from sklearn.metrics import explained_variance_score
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn import metrics

# Cross-validation
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_validate

#from sklearn import preprocessing
#from sklearn.pipeline import make_pipeline
from xgboost import XGBRegressor
from xgboost import XGBRFRegressor
#from sklearn.model_selection import GridSearchCV
#from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# # Import prepared dataframes

# %%
# Bitcoin
df_btc = pd.read_csv('df_btc.csv')
df_btc.Date = pd.to_datetime(df_btc.Date)

# Twitter
df_tw = pd.read_csv('df_tw_agg.csv')
df_tw.Date = pd.to_datetime(df_tw.Date)

# %% [markdown]
# # Construct the analysis dataframe

# %% [markdown]
# ### Select the Twitter variables to be used

# %%
variables = ['Date',
 'tw_neg_sum',
 'tw_neg_mean',
 'tw_neg_std',
 'tw_pos_sum',
 'tw_pos_mean',
 'tw_pos_std',
 'tw_comp_sum',
 'tw_comp_mean',
 'tw_comp_std',
 'tw_RelDiffPosNeg_sum',
 'tw_RelDiffPosNeg_mean',
 'tw_RelDiffPosNeg_std',
 'tw_Like_Count_sum',
 'tw_Like_Count_mean',
 'tw_Like_Count_std',
 'tw_Reply_Count_sum',
 'tw_Reply_Count_mean',
 'tw_Reply_Count_std',
 'tw_Retweet_Count_sum',
 'tw_Retweet_Count_mean',
 'tw_Retweet_Count_std',
 'tw_Quote_Count_sum',
 'tw_Quote_Count_mean',
 'tw_Quote_Count_std',
 'tw_comp_q5_count',
 'tw_comp_q4_count',
 'tw_comp_q3_count',
 'tw_comp_q2_count',
 'tw_comp_q1_count',
 'tw_N',
 'tw_N_pos',
 'tw_N_neg',
'tw_neg_sum_last5_mean',
 'tw_neg_sum_last5_std',
 'tw_neg_sum_last10_mean',
 'tw_neg_sum_last10_std',
 'tw_pos_sum_last5_mean',
 'tw_pos_sum_last5_std',
 'tw_pos_sum_last10_mean',
 'tw_pos_sum_last10_std',
 'tw_comp_sum_last5_mean',
 'tw_comp_sum_last5_std',
 'tw_comp_sum_last10_mean',
 'tw_comp_sum_last10_std',
 'tw_RelDiffPosNeg_sum_last5_mean',
 'tw_RelDiffPosNeg_sum_last5_std',
 'tw_RelDiffPosNeg_sum_last10_mean',
 'tw_RelDiffPosNeg_sum_last10_std',
 'tw_Like_Count_sum_last5_mean',
 'tw_Like_Count_sum_last5_std',
 'tw_Like_Count_sum_last10_mean',
 'tw_Like_Count_sum_last10_std',
 'tw_Reply_Count_sum_last5_mean',
 'tw_Reply_Count_sum_last5_std',
 'tw_Reply_Count_sum_last10_mean',
 'tw_Reply_Count_sum_last10_std',
 'tw_Retweet_Count_sum_last5_mean',
 'tw_Retweet_Count_sum_last5_std',
 'tw_Retweet_Count_sum_last10_mean',
 'tw_Retweet_Count_sum_last10_std',
 'tw_Quote_Count_sum_last5_mean',
 'tw_Quote_Count_sum_last5_std',
 'tw_Quote_Count_sum_last10_mean',
 'tw_Quote_Count_sum_last10_std',
 'tw_N_last5_mean',
 'tw_N_last5_std',
 'tw_N_last10_mean',
 'tw_N_last10_std',
 'tw_N_pos_last5_mean',
 'tw_N_pos_last5_std',
 'tw_N_pos_last10_mean',
 'tw_N_pos_last10_std',
 'tw_N_neg_last5_mean',
 'tw_N_neg_last5_std',
 'tw_N_neg_last10_mean',
 'tw_N_neg_last10_std']

# %% [markdown]
# ### Merge Bitcoin and Twitter dataframes

# %%
# Apply selection on the BTC dataframe
df_ana = df_btc[(df_btc.Date >= pd.to_datetime('01-04-2020', format='%d-%m-%Y')) & \
       (df_btc.Date < pd.to_datetime('15-03-2021', format='%d-%m-%Y'))]
#df_ana = df_ana[['Date', 'Close', 'Close_next1', 'Close_diff_next1', 'Close_diff_next1_rel', 'Close_diff_next1_sgn']]
df_ana = df_ana.dropna()

# Merge with TW dataframe
df_ana = pd.merge(left=df_ana, right=df_tw[variables], how='inner', left_on='Date', right_on='Date')
df_ana.dropna(inplace=True)

# %% [markdown]
# ### Study correlations among features

# %%
corr = df_ana.corr()
plt.figure(figsize = (20,20))
sb.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Target: next day's Bitcoin Close price

# %% [markdown]
# ### Prepare training and testing datasets

# %%
# Define target and input variables
target = 'Close_next1'
variables = df_ana.columns.to_list()

# Split
y = df_ana[target]
X = df_ana[variables]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
#X_test.sort_values(by=['Date'], inplace=True)

# Remove all variables derived from the BTC Close price
skip_pattern = 'Close'

X_train_tmp = X_train[X_train.columns.drop(list(X_train.filter(like=skip_pattern)))].copy(deep=True)
X_train_tmp.drop(columns=['Date'], inplace=True)

X_test_tmp = X_test[X_test.columns.drop(list(X_test.filter(like=skip_pattern)))].copy(deep=True)
X_test_tmp.drop(columns=['Date'], inplace=True)

# %% [markdown]
# ### Prepare and train the model

# %%
model = xgb.XGBRegressor(n_estimators = 1000,\
                        learning_rate = 0.01,\
                        max_depth = 5,\
                        min_split_loss = 10,\
                        min_child_weight = 1,\
                        colsample_bytree = 0.7,\
                        subsample = 0.5,\
                        reg_lambda = 2,\
                        reg_alpha = 0)

#model.fit(X_train_tmp.drop(columns=['Date']),y_train)
model.fit(X_train_tmp,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=10, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=5,
#              min_child_weight=1, min_split_loss=10, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=4,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=2,
#              scale_pos_weight=1, subsample=0.5, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %% [markdown]
# ### Compute extra features for performance evaluation

# %%
y_pred=model.predict(X_test_tmp)
X_test['Pred_next1'] = list(y_pred)
X_test['Pred_diff_next1'] = (X_test.Pred_next1 - X_test.Close).to_list()
X_test['Pred_diff_next1_rel'] = (X_test.Pred_diff_next1/X_test.Close).to_list()
X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1)
# Out:
# <ipython-input-7-e9ddb46e0ea7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_next1'] = list(y_pred)
# <ipython-input-7-e9ddb46e0ea7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1'] = (X_test.Pred_next1 - X_test.Close).to_list()
# <ipython-input-7-e9ddb46e0ea7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_rel'] = (X_test.Pred_diff_next1/X_test.Close).to_list()
# <ipython-input-7-e9ddb46e0ea7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1)

# %% [markdown]
# ### Performance evaluation

# %%
print('==================================================================================')
print('Performance on the target variable: next day\'s BTC Close price' )
test = X_test['Close_next1']
pred = X_test['Pred_next1']
print('+++ Next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the absolute diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1']
pred = X_test['Pred_diff_next1']
print('+++ Diff to next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the relative diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_rel']
pred = X_test['Pred_diff_next1_rel']
print('+++ Relative diff to next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the signed diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_sgn']
pred = X_test['Pred_diff_next1_sgn']
print('+++ Next day BTC price')
print(f"Accuracy:    {accuracy_score(test, pred)}")
# Out:
# ==================================================================================
# Performance on the target variable: next day's BTC Close price
# +++ Next day BTC price
# Explained variance:    0.9769932187487691
# R2:                    0.97698381066743
# MAE:                   1026.7042910401121
# MSE:                   3324159.6433078405
#
# ==================================================================================
# Performance on the absolute diff between today's and next day's BTC Close price
# +++ Diff to next day BTC price
# Explained variance:    -3.1557800738911768
# R2:                    -3.1574794822758436
# MAE:                   1026.7042910401121
# MSE:                   3324159.6433078405
#
# ==================================================================================
# Performance on the relative diff between today's and next day's BTC Close price
# +++ Relative diff to next day BTC price
# Explained variance:    -3.012418441944993
# R2:                    -977.0167157054382
# MAE:                   1.001898256871797
# MSE:                   1.0079352796813559
#
# ==================================================================================
# Performance on the signed diff between today's and next day's BTC Close price
# +++ Next day BTC price
# Accuracy:    0.5074626865671642

# %% [markdown]
# ### Plot predictions

# %%
# Next day's BTC price

X_test.sort_values(by=['Date'], inplace=True)
x = X_test.Date
y_test = X_test['Close_next1']
y_pred = X_test['Pred_next1']

fig, ax = plt.subplots(figsize=(15, 5))

ax.set_xlabel('Date')
ax.set_ylabel('Next day BTC price')
ax.plot(x, y_test, color='tab:red', label='Ground Truth')
ax.plot(x, y_pred, color='tab:blue', label='Prediction')

plt.legend()
#ax1.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
# Out:
# <ipython-input-9-c9312ce135ef>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.sort_values(by=['Date'], inplace=True)

# %%
# Absolute diff to next day's BTC price

x = X_test.Date
y_test = X_test['Close_diff_next1']
y_pred = X_test['Pred_diff_next1']

fig, ax = plt.subplots(figsize=(15, 5))

ax.set_xlabel('Date')
ax.set_ylabel('Absolute diff to next day\'s BTC price')
ax.plot(x, y_test, color='tab:red', label='Ground Truth')
ax.plot(x, y_pred, color='tab:blue', label='Prediction')

plt.legend()
#ax1.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
# Relative diff to next day's BTC price

x = X_test.Date
y_test = X_test['Close_diff_next1_rel']
y_pred = X_test['Pred_diff_next1_rel']

fig, ax = plt.subplots(figsize=(15, 5))

ax.set_xlabel('Date')
ax.set_ylabel('Relative diff to next day\'s BTC price')
ax.plot(x, y_test, color='tab:red', label='Ground Truth')
ax.plot(x, y_pred, color='tab:blue', label='Prediction')

plt.legend()
#ax1.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
# Signed diff to next day's BTC price

x = X_test.Date
y_test = X_test['Close_diff_next1_sgn']
y_pred = X_test['Pred_diff_next1_sgn']

fig, ax = plt.subplots(figsize=(15, 5))

ax.set_xlabel('Date')
ax.set_ylabel('Relative diff to next day\'s BTC price')
ax.plot(x, y_test, color='tab:red', label='Ground Truth')
ax.plot(x, y_pred, color='tab:blue', label='Prediction')

plt.legend()
#ax1.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %% [markdown]
# ### Feature importance

# %%
import operator

for importance_type in ['weight', 'gain', 'cover']:

    # Get the importance dictionary (by gain) from the booster
    importance = model.get_booster().get_score(importance_type=importance_type)

    # make your changes
    for key in importance.keys():
        importance[key] = round(importance[key],2)
        
    print('==============')
    print(f'Importance type: {importance_type}')
    print(dict(sorted(importance.items(),
                            key=operator.itemgetter(1),
                            reverse=True)))

    # provide the importance dictionary to the plotting function
    #ax = plot_importance(importance, max_num_features=3, importance_type='gain', show_values=True)

    # Plot variable importance
    ax = xgb.plot_importance(importance, max_num_features=10, grid=False, xlabel=None,\
                             title='Feature importance according to '+importance_type)
    fig = ax.figure
    fig.set_size_inches(10, 10)
# Out:
# ==============
# Importance type: weight
# {'tw_neg_sum': 1096, 'tw_neg_mean': 674, 'tw_neg_std': 493, 'tw_pos_std': 410, 'tw_pos_mean': 385, 'tw_Retweet_Count_sum_last10_mean': 334, 'tw_pos_sum': 299, 'tw_comp_std': 277, 'tw_Reply_Count_mean': 265, 'tw_RelDiffPosNeg_std': 260, 'tw_comp_sum': 259, 'tw_Like_Count_mean': 258, 'tw_Like_Count_sum': 251, 'tw_RelDiffPosNeg_sum_last10_mean': 240, 'tw_neg_sum_last10_mean': 240, 'tw_comp_sum_last10_std': 233, 'tw_neg_sum_last10_std': 225, 'tw_pos_sum_last10_mean': 214, 'tw_RelDiffPosNeg_sum': 210, 'tw_comp_sum_last10_mean': 209, 'tw_Reply_Count_sum_last5_std': 204, 'tw_Retweet_Count_mean': 204, 'tw_comp_mean': 197, 'tw_neg_sum_last5_std': 189, 'tw_Like_Count_std': 187, 'tw_Quote_Count_sum_last10_mean': 183, 'tw_Reply_Count_sum_last10_std': 182, 'tw_pos_sum_last10_std': 180, 'tw_Retweet_Count_std': 180, 'tw_N_neg_last10_std': 174, 'tw_Reply_Count_std': 174, 'tw_RelDiffPosNeg_mean': 169, 'tw_RelDiffPosNeg_sum_last5_std': 169, 'tw_Quote_Count_sum_last10_std': 167, 'tw_comp_sum_last5_std': 161, 'tw_Like_Count_sum_last10_mean': 158, 'tw_Retweet_Count_sum_last5_std': 158, 'tw_comp_q4_count': 157, 'tw_Quote_Count_mean': 155, 'tw_pos_sum_last5_std': 155, 'tw_neg_sum_last5_mean': 154, 'tw_Quote_Count_sum_last5_std': 153, 'tw_Reply_Count_sum': 152, 'tw_Like_Count_sum_last5_std': 150, 'tw_Quote_Count_std': 147, 'tw_Retweet_Count_sum_last10_std': 145, 'tw_Reply_Count_sum_last5_mean': 144, 'tw_comp_q2_count': 144, 'tw_Like_Count_sum_last10_std': 143, 'tw_Retweet_Count_sum': 143, 'tw_pos_sum_last5_mean': 140, 'tw_Reply_Count_sum_last10_mean': 139, 'tw_RelDiffPosNeg_sum_last10_std': 136, 'tw_Quote_Count_sum_last5_mean': 136, 'tw_Retweet_Count_sum_last5_mean': 129, 'tw_Quote_Count_sum': 129, 'tw_RelDiffPosNeg_sum_last5_mean': 119, 'tw_comp_q3_count': 118, 'tw_comp_sum_last5_mean': 114, 'tw_N_last10_mean': 108, 'tw_comp_q5_count': 102, 'tw_N_pos_last5_mean': 96, 'tw_N_neg_last5_std': 96, 'tw_N_neg_last10_mean': 78, 'tw_Like_Count_sum_last5_mean': 71, 'tw_N_neg_last5_mean': 60, 'tw_N_neg': 60, 'tw_N_pos_last5_std': 60, 'tw_N_pos_last10_mean': 58, 'tw_comp_q1_count': 58, 'tw_N_last5_mean': 57, 'tw_N_last10_std': 56, 'tw_N_last5_std': 56, 'tw_N_pos': 37, 'tw_N_pos_last10_std': 35, 'tw_N': 33}
# ==============
# Importance type: gain
# {'tw_N_neg_last10_mean': 2376939447.76, 'tw_neg_sum_last10_mean': 1963441261.22, 'tw_N_last5_mean': 1328746968.06, 'tw_N_pos_last5_mean': 585052227.54, 'tw_pos_sum_last10_mean': 543944628.79, 'tw_Like_Count_sum_last10_mean': 386213449.61, 'tw_Retweet_Count_sum_last10_mean': 332463660.24, 'tw_pos_sum_last5_mean': 226365776.9, 'tw_neg_sum_last5_mean': 184448823.5, 'tw_N_last10_mean': 179751359.5, 'tw_N_neg_last5_mean': 166480049.84, 'tw_Retweet_Count_sum_last5_mean': 94640605.33, 'tw_RelDiffPosNeg_sum_last10_mean': 91238161.77, 'tw_N_pos_last10_mean': 88142282.06, 'tw_comp_sum_last5_mean': 71845797.47, 'tw_comp_sum_last10_mean': 68701400.9, 'tw_RelDiffPosNeg_sum_last5_mean': 49433026.31, 'tw_Like_Count_sum': 29483630.8, 'tw_RelDiffPosNeg_sum': 28378039.73, 'tw_Retweet_Count_sum': 25768271.8, 'tw_N_neg_last10_std': 24451388.76, 'tw_neg_sum_last10_std': 16538572.11, 'tw_N_last10_std': 12420423.28, 'tw_N': 10048582.16, 'tw_Reply_Count_sum_last10_mean': 9595040.06, 'tw_N_pos': 9387540.81, 'tw_N_neg_last5_std': 9333355.1, 'tw_comp_q4_count': 9162472.51, 'tw_N_neg': 7921320.58, 'tw_neg_sum_last5_std': 7712068.07, 'tw_Like_Count_sum_last5_mean': 6358464.38, 'tw_RelDiffPosNeg_mean': 6324575.94, 'tw_comp_q3_count': 5827282.03, 'tw_Reply_Count_sum_last10_std': 5341621.69, 'tw_Reply_Count_sum_last5_std': 5092053.74, 'tw_comp_sum': 4132442.9, 'tw_Like_Count_sum_last10_std': 4021271.63, 'tw_pos_sum_last5_std': 3851732.49, 'tw_comp_q5_count': 3829970.44, 'tw_comp_q2_count': 3695072.22, 'tw_comp_sum_last5_std': 3603665.65, 'tw_Like_Count_mean': 3427627.49, 'tw_Quote_Count_sum_last10_mean': 3406017.59, 'tw_Quote_Count_sum_last10_std': 3390419.96, 'tw_Retweet_Count_mean': 3332747.93, 'tw_RelDiffPosNeg_sum_last10_std': 3301914.75, 'tw_RelDiffPosNeg_std': 3280875.2, 'tw_Like_Count_std': 3067161.79, 'tw_N_pos_last10_std': 2988720.86, 'tw_Retweet_Count_sum_last10_std': 2851854.84, 'tw_N_pos_last5_std': 2736709.44, 'tw_comp_sum_last10_std': 2691404.87, 'tw_pos_sum': 2689382.71, 'tw_comp_std': 2635144.0, 'tw_Reply_Count_sum_last5_mean': 2592890.37, 'tw_pos_sum_last10_std': 2450238.87, 'tw_pos_std': 2429369.81, 'tw_Quote_Count_sum_last5_mean': 2411345.23, 'tw_N_last5_std': 2347285.07, 'tw_Retweet_Count_sum_last5_std': 2326017.99, 'tw_Reply_Count_mean': 2256502.3, 'tw_Quote_Count_sum': 2070995.42, 'tw_RelDiffPosNeg_sum_last5_std': 2042173.04, 'tw_Quote_Count_std': 1985556.07, 'tw_comp_mean': 1979982.28, 'tw_Quote_Count_sum_last5_std': 1941497.01, 'tw_Reply_Count_sum': 1834195.94, 'tw_Like_Count_sum_last5_std': 1659337.72, 'tw_Retweet_Count_std': 1603122.43, 'tw_comp_q1_count': 1560377.68, 'tw_Quote_Count_mean': 1546918.86, 'tw_pos_mean': 1369730.33, 'tw_neg_std': 1287337.34, 'tw_Reply_Count_std': 1156513.14, 'tw_neg_mean': 1086710.92, 'tw_neg_sum': 791569.12}
# ==============
# Importance type: cover
# {'tw_N_pos_last5_mean': 96.42, 'tw_N_last5_mean': 95.02, 'tw_Retweet_Count_sum_last10_mean': 92.98, 'tw_N_last10_mean': 84.2, 'tw_RelDiffPosNeg_sum_last10_mean': 83.98, 'tw_N_neg_last10_mean': 82.37, 'tw_N_pos': 80.35, 'tw_RelDiffPosNeg_sum_last5_mean': 79.51, 'tw_N_pos_last10_mean': 79.34, 'tw_pos_sum_last10_mean': 76.36, 'tw_Like_Count_sum_last10_mean': 75.11, 'tw_neg_sum_last10_mean': 69.73, 'tw_Like_Count_sum': 68.17, 'tw_Retweet_Count_sum': 68.01, 'tw_comp_sum_last10_mean': 66.29, 'tw_N_neg_last5_mean': 66.02, 'tw_RelDiffPosNeg_sum': 65.52, 'tw_comp_q4_count': 63.2, 'tw_N_neg': 60.95, 'tw_N': 58.36, 'tw_comp_q5_count': 58.31, 'tw_Reply_Count_sum_last10_mean': 57.71, 'tw_Like_Count_sum_last5_mean': 57.46, 'tw_pos_sum_last5_mean': 57.23, 'tw_Quote_Count_sum_last5_mean': 56.95, 'tw_Retweet_Count_sum_last5_std': 56.39, 'tw_comp_sum_last5_mean': 56.03, 'tw_comp_q2_count': 55.55, 'tw_Retweet_Count_sum_last5_mean': 55.5, 'tw_Reply_Count_sum_last10_std': 53.5, 'tw_comp_sum_last10_std': 53.48, 'tw_Retweet_Count_sum_last10_std': 52.47, 'tw_RelDiffPosNeg_sum_last10_std': 51.95, 'tw_Quote_Count_sum_last10_std': 51.93, 'tw_Quote_Count_sum_last5_std': 48.73, 'tw_Reply_Count_sum_last5_mean': 47.49, 'tw_Quote_Count_sum_last10_mean': 46.43, 'tw_Like_Count_sum_last10_std': 46.41, 'tw_comp_q3_count': 45.9, 'tw_N_pos_last10_std': 44.63, 'tw_pos_sum_last10_std': 44.39, 'tw_Retweet_Count_std': 44.26, 'tw_Quote_Count_std': 44.14, 'tw_Reply_Count_sum_last5_std': 43.98, 'tw_Like_Count_std': 43.7, 'tw_comp_q1_count': 43.45, 'tw_comp_sum': 42.95, 'tw_N_neg_last10_std': 40.73, 'tw_Quote_Count_sum': 40.72, 'tw_Quote_Count_mean': 39.66, 'tw_N_last10_std': 39.16, 'tw_Like_Count_sum_last5_std': 37.87, 'tw_N_neg_last5_std': 37.82, 'tw_Like_Count_mean': 37.12, 'tw_N_pos_last5_std': 36.87, 'tw_Reply_Count_mean': 36.81, 'tw_neg_sum_last10_std': 35.24, 'tw_comp_sum_last5_std': 33.52, 'tw_pos_sum_last5_std': 33.28, 'tw_neg_sum_last5_std': 32.96, 'tw_RelDiffPosNeg_sum_last5_std': 32.88, 'tw_comp_mean': 32.1, 'tw_N_last5_std': 32.05, 'tw_RelDiffPosNeg_mean': 31.89, 'tw_pos_sum': 30.6, 'tw_Retweet_Count_mean': 30.28, 'tw_RelDiffPosNeg_std': 29.47, 'tw_Reply_Count_sum': 29.01, 'tw_comp_std': 27.81, 'tw_neg_sum_last5_mean': 27.21, 'tw_Reply_Count_std': 22.73, 'tw_pos_mean': 21.57, 'tw_neg_std': 21.52, 'tw_pos_std': 21.14, 'tw_neg_mean': 10.71, 'tw_neg_sum': 9.07}

# %% [markdown]
# ## Target: Absolute difference to the next day's BTC Close price

# %% [markdown]
# ### Prepare training and testing datasets

# %%
# Define target and input variables
target = 'Close_diff_next1'
variables = df_ana.columns.to_list()

# Split
y = df_ana[target]
X = df_ana[variables]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Remove all variables derived from the BTC Close price
skip_pattern = 'Close'

X_train_tmp = X_train[X_train.columns.drop(list(X_train.filter(like=skip_pattern)))].copy(deep=True)
X_train_tmp.drop(columns=['Date'], inplace=True)

X_test_tmp = X_test[X_test.columns.drop(list(X_test.filter(like=skip_pattern)))].copy(deep=True)
X_test_tmp.drop(columns=['Date'], inplace=True)

# %% [markdown]
# ### Prepare and train the model

# %%
model = xgb.XGBRegressor(n_estimators = 1000,\
                        learning_rate = 0.01,\
                        max_depth = 5,\
                        min_split_loss = 10,\
                        min_child_weight = 1,\
                        colsample_bytree = 0.7,\
                        subsample = 0.5,\
                        reg_lambda = 2,\
                        reg_alpha = 0)

#model.fit(X_train_tmp.drop(columns=['Date']),y_train)
model.fit(X_train_tmp,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=10, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=5,
#              min_child_weight=1, min_split_loss=10, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=4,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=2,
#              scale_pos_weight=1, subsample=0.5, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %% [markdown]
# ### Compute extra features for performance evaluation

# %%
y_pred=model.predict(X_test_tmp)

X_test['Pred_diff_next1'] = list(y_pred)
X_test['Pred_diff_next1_rel'] = (X_test.Pred_diff_next1/X_test.Close).to_list()
X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1)
# Out:
# <ipython-input-16-b6d71e7a9ad9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1'] = list(y_pred)
# <ipython-input-16-b6d71e7a9ad9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_rel'] = (X_test.Pred_diff_next1/X_test.Close).to_list()
# <ipython-input-16-b6d71e7a9ad9>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1)

# %% [markdown]
# ### Performance evaluation

# %%
print('==================================================================================')
print('Performance on the absolute diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1']
pred = X_test['Pred_diff_next1']
print('+++ Diff to next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the relative diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_rel']
pred = X_test['Pred_diff_next1_rel']
print('+++ Relative diff to next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the signed diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_sgn']
pred = X_test['Pred_diff_next1_sgn']
print('+++ Next day BTC price')
print(f"Accuracy:    {accuracy_score(test, pred)}")
# Out:
# ==================================================================================
# Performance on the absolute diff between today's and next day's BTC Close price
# +++ Diff to next day BTC price
# Explained variance:    -0.09350060078597089
# R2:                    -0.1082947886464205
# MAE:                   536.0376547242979
# MSE:                   886149.6069945932
#
# ==================================================================================
# Performance on the relative diff between today's and next day's BTC Close price
# +++ Relative diff to next day BTC price
# Explained variance:    -0.21861728903710853
# R2:                    -965.7415333801905
# MAE:                   0.9975265818740103
# MSE:                   0.9963151776238368
#
# ==================================================================================
# Performance on the signed diff between today's and next day's BTC Close price
# +++ Next day BTC price
# Accuracy:    0.47761194029850745

# %%
import operator

for importance_type in ['weight', 'gain', 'cover']:

    # Get the importance dictionary (by gain) from the booster
    importance = model.get_booster().get_score(importance_type=importance_type)

    # make your changes
    for key in importance.keys():
        importance[key] = round(importance[key],2)
        
    print('==============')
    print(f'Importance type: {importance_type}')
    print(dict(sorted(importance.items(),
                            key=operator.itemgetter(1),
                            reverse=True)))

    # provide the importance dictionary to the plotting function
    #ax = plot_importance(importance, max_num_features=3, importance_type='gain', show_values=True)

    # Plot variable importance
    ax = xgb.plot_importance(importance, max_num_features=10, grid=False, xlabel=None,\
                             title='Feature importance according to '+importance_type)
    fig = ax.figure
    fig.set_size_inches(10, 10)
# Out:
# ==============
# Importance type: weight
# {'tw_neg_sum': 1401, 'tw_neg_mean': 941, 'tw_neg_std': 582, 'tw_pos_std': 442, 'tw_pos_mean': 409, 'tw_comp_std': 362, 'tw_RelDiffPosNeg_std': 334, 'tw_pos_sum': 332, 'tw_neg_sum_last10_mean': 299, 'tw_Retweet_Count_mean': 296, 'tw_Retweet_Count_sum_last10_std': 286, 'tw_comp_sum': 279, 'tw_Retweet_Count_sum_last5_std': 266, 'tw_Reply_Count_mean': 244, 'tw_Like_Count_mean': 237, 'tw_Quote_Count_sum_last5_std': 232, 'tw_Reply_Count_sum': 231, 'tw_Quote_Count_sum_last10_std': 214, 'tw_comp_mean': 213, 'tw_neg_sum_last5_std': 202, 'tw_Quote_Count_std': 197, 'tw_RelDiffPosNeg_mean': 197, 'tw_Reply_Count_sum_last5_mean': 184, 'tw_neg_sum_last10_std': 178, 'tw_neg_sum_last5_mean': 177, 'tw_Like_Count_std': 177, 'tw_Like_Count_sum_last10_std': 175, 'tw_Reply_Count_std': 174, 'tw_Quote_Count_mean': 171, 'tw_comp_sum_last10_std': 170, 'tw_RelDiffPosNeg_sum': 164, 'tw_Retweet_Count_std': 158, 'tw_comp_q5_count': 153, 'tw_RelDiffPosNeg_sum_last5_std': 152, 'tw_Like_Count_sum_last5_std': 143, 'tw_RelDiffPosNeg_sum_last10_std': 142, 'tw_Reply_Count_sum_last10_mean': 138, 'tw_pos_sum_last5_std': 138, 'tw_Like_Count_sum': 136, 'tw_comp_sum_last5_std': 135, 'tw_Retweet_Count_sum_last5_mean': 133, 'tw_pos_sum_last10_mean': 131, 'tw_comp_q3_count': 129, 'tw_comp_q4_count': 129, 'tw_Retweet_Count_sum': 128, 'tw_Reply_Count_sum_last5_std': 128, 'tw_N_neg_last10_std': 126, 'tw_Reply_Count_sum_last10_std': 123, 'tw_comp_sum_last10_mean': 121, 'tw_Like_Count_sum_last10_mean': 116, 'tw_Quote_Count_sum_last10_mean': 111, 'tw_N_last5_std': 108, 'tw_N_neg': 102, 'tw_comp_sum_last5_mean': 102, 'tw_Quote_Count_sum': 102, 'tw_pos_sum_last10_std': 101, 'tw_comp_q2_count': 99, 'tw_pos_sum_last5_mean': 97, 'tw_N_neg_last5_mean': 95, 'tw_Retweet_Count_sum_last10_mean': 93, 'tw_Like_Count_sum_last5_mean': 91, 'tw_N_neg_last5_std': 84, 'tw_RelDiffPosNeg_sum_last5_mean': 83, 'tw_Quote_Count_sum_last5_mean': 83, 'tw_comp_q1_count': 82, 'tw_N_last10_std': 79, 'tw_N_pos_last5_std': 77, 'tw_N_neg_last10_mean': 76, 'tw_N_last10_mean': 72, 'tw_RelDiffPosNeg_sum_last10_mean': 72, 'tw_N_last5_mean': 56, 'tw_N_pos_last10_std': 55, 'tw_N': 42, 'tw_N_pos_last5_mean': 37, 'tw_N_pos_last10_mean': 32, 'tw_N_pos': 22}
# ==============
# Importance type: gain
# {'tw_Reply_Count_sum_last10_mean': 3707786.85, 'tw_comp_q4_count': 3620128.84, 'tw_Retweet_Count_sum_last10_mean': 3184598.76, 'tw_Like_Count_sum_last5_mean': 3096415.78, 'tw_N_last5_mean': 2992604.51, 'tw_N_last10_mean': 2855771.64, 'tw_neg_sum_last10_mean': 2840042.61, 'tw_Like_Count_sum_last10_std': 2704684.77, 'tw_N': 2671263.56, 'tw_Like_Count_sum_last10_mean': 2562644.42, 'tw_N_neg_last5_mean': 2555589.29, 'tw_comp_sum_last10_mean': 2358502.12, 'tw_Retweet_Count_sum_last5_mean': 2327505.2, 'tw_N_pos_last5_mean': 2250814.01, 'tw_Reply_Count_sum_last10_std': 2193442.17, 'tw_Retweet_Count_sum_last10_std': 2127051.16, 'tw_RelDiffPosNeg_sum_last10_mean': 2070765.06, 'tw_pos_sum_last10_mean': 2055290.83, 'tw_N_neg': 2032820.18, 'tw_Quote_Count_sum_last10_mean': 1998330.38, 'tw_N_pos_last10_std': 1997491.87, 'tw_neg_sum_last5_mean': 1961647.43, 'tw_N_pos': 1944628.28, 'tw_RelDiffPosNeg_sum': 1939396.46, 'tw_N_pos_last10_mean': 1939334.18, 'tw_N_neg_last10_std': 1921019.62, 'tw_Quote_Count_sum_last5_mean': 1916329.13, 'tw_RelDiffPosNeg_sum_last10_std': 1908395.16, 'tw_comp_q2_count': 1883651.17, 'tw_RelDiffPosNeg_sum_last5_mean': 1850216.71, 'tw_N_neg_last5_std': 1785974.34, 'tw_N_neg_last10_mean': 1738200.99, 'tw_Quote_Count_sum_last10_std': 1689292.17, 'tw_comp_sum_last10_std': 1675502.57, 'tw_pos_sum_last5_mean': 1666965.53, 'tw_comp_q5_count': 1621999.83, 'tw_Like_Count_sum': 1459186.97, 'tw_Retweet_Count_sum_last5_std': 1453014.47, 'tw_Reply_Count_sum_last5_mean': 1322700.95, 'tw_Like_Count_sum_last5_std': 1321929.38, 'tw_Reply_Count_sum_last5_std': 1299809.55, 'tw_Quote_Count_sum_last5_std': 1293656.13, 'tw_comp_q1_count': 1285990.36, 'tw_N_last10_std': 1252616.16, 'tw_comp_sum_last5_mean': 1216975.13, 'tw_Retweet_Count_sum': 1170708.66, 'tw_comp_q3_count': 1119024.92, 'tw_Quote_Count_mean': 1076716.27, 'tw_pos_std': 1070490.33, 'tw_neg_sum_last10_std': 1065612.58, 'tw_pos_mean': 1060164.95, 'tw_Reply_Count_mean': 1049144.09, 'tw_Like_Count_mean': 1030018.14, 'tw_N_pos_last5_std': 1012643.19, 'tw_neg_sum_last5_std': 999910.94, 'tw_Reply_Count_sum': 994607.64, 'tw_comp_sum_last5_std': 966788.13, 'tw_comp_sum': 965320.32, 'tw_pos_sum': 944782.36, 'tw_Retweet_Count_std': 939034.51, 'tw_comp_mean': 847693.72, 'tw_RelDiffPosNeg_std': 839953.6, 'tw_comp_std': 801611.85, 'tw_RelDiffPosNeg_mean': 743699.25, 'tw_pos_sum_last5_std': 720298.29, 'tw_N_last5_std': 710543.38, 'tw_Quote_Count_sum': 697985.59, 'tw_pos_sum_last10_std': 643604.33, 'tw_Reply_Count_std': 611105.49, 'tw_Quote_Count_std': 597590.75, 'tw_Like_Count_std': 589899.92, 'tw_RelDiffPosNeg_sum_last5_std': 569150.27, 'tw_neg_std': 538116.99, 'tw_Retweet_Count_mean': 480277.87, 'tw_neg_mean': 405829.61, 'tw_neg_sum': 364775.03}
# ==============
# Importance type: cover
# {'tw_Retweet_Count_sum_last10_std': 104.88, 'tw_N_last10_mean': 99.72, 'tw_N_neg_last5_mean': 98.96, 'tw_N_pos_last5_mean': 95.54, 'tw_Retweet_Count_sum_last10_mean': 94.59, 'tw_N_neg_last10_std': 93.43, 'tw_Like_Count_sum_last10_mean': 93.12, 'tw_Retweet_Count_sum_last5_std': 92.12, 'tw_N_neg_last10_mean': 90.57, 'tw_N_pos_last10_mean': 87.81, 'tw_Like_Count_sum_last10_std': 87.15, 'tw_Quote_Count_sum_last10_std': 87.07, 'tw_N_last5_mean': 87.05, 'tw_neg_sum_last10_mean': 86.6, 'tw_Like_Count_sum_last5_mean': 86.45, 'tw_Retweet_Count_sum_last5_mean': 82.08, 'tw_RelDiffPosNeg_sum_last10_mean': 80.65, 'tw_RelDiffPosNeg_sum_last5_mean': 77.49, 'tw_RelDiffPosNeg_sum_last10_std': 75.92, 'tw_N_pos': 73.91, 'tw_comp_sum_last10_mean': 72.7, 'tw_comp_sum_last10_std': 72.02, 'tw_comp_q4_count': 70.98, 'tw_Quote_Count_sum_last5_std': 68.95, 'tw_pos_sum_last5_mean': 67.94, 'tw_pos_sum_last10_mean': 67.79, 'tw_N_pos_last10_std': 65.78, 'tw_Reply_Count_sum_last10_std': 65.68, 'tw_comp_sum_last5_mean': 65.41, 'tw_Quote_Count_sum_last10_mean': 65.14, 'tw_N': 64.38, 'tw_Reply_Count_sum_last5_std': 64.2, 'tw_N_last10_std': 62.25, 'tw_Reply_Count_sum_last5_mean': 60.18, 'tw_N_neg': 59.71, 'tw_comp_q2_count': 58.6, 'tw_RelDiffPosNeg_sum_last5_std': 58.27, 'tw_Reply_Count_sum_last10_mean': 57.36, 'tw_comp_q5_count': 55.62, 'tw_neg_sum_last10_std': 54.12, 'tw_comp_q3_count': 53.71, 'tw_Retweet_Count_mean': 53.54, 'tw_RelDiffPosNeg_sum': 53.49, 'tw_neg_sum_last5_mean': 52.12, 'tw_N_neg_last5_std': 51.48, 'tw_N_pos_last5_std': 51.01, 'tw_Quote_Count_sum_last5_mean': 48.3, 'tw_N_last5_std': 48.16, 'tw_Reply_Count_mean': 47.6, 'tw_RelDiffPosNeg_mean': 46.57, 'tw_comp_q1_count': 46.51, 'tw_Quote_Count_std': 45.4, 'tw_Like_Count_std': 43.44, 'tw_Like_Count_mean': 43.16, 'tw_Retweet_Count_sum': 42.66, 'tw_Like_Count_sum_last5_std': 41.49, 'tw_Like_Count_sum': 40.21, 'tw_neg_sum_last5_std': 40.12, 'tw_Reply_Count_std': 36.2, 'tw_RelDiffPosNeg_std': 36.02, 'tw_Retweet_Count_std': 35.46, 'tw_pos_sum_last10_std': 34.75, 'tw_Reply_Count_sum': 33.76, 'tw_pos_sum_last5_std': 33.72, 'tw_comp_sum_last5_std': 33.64, 'tw_Quote_Count_sum': 31.62, 'tw_Quote_Count_mean': 29.78, 'tw_comp_mean': 28.85, 'tw_comp_std': 22.54, 'tw_comp_sum': 22.49, 'tw_pos_std': 21.26, 'tw_neg_std': 19.11, 'tw_pos_mean': 19.07, 'tw_pos_sum': 14.59, 'tw_neg_mean': 10.67, 'tw_neg_sum': 8.69}

# %% [markdown]
# ## Target: Relative difference to the next day's BTC Close price

# %% [markdown]
# ### Prepare training and testing datasets

# %%
# Define target and input variables
target = 'Close_diff_next1_rel'
variables = df_ana.columns.to_list()

# Split
y = df_ana[target]
X = df_ana[variables]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Remove all variables derived from the BTC Close price
skip_pattern = 'Close'

X_train_tmp = X_train[X_train.columns.drop(list(X_train.filter(like=skip_pattern)))].copy(deep=True)
X_train_tmp.drop(columns=['Date'], inplace=True)

X_test_tmp = X_test[X_test.columns.drop(list(X_test.filter(like=skip_pattern)))].copy(deep=True)
X_test_tmp.drop(columns=['Date'], inplace=True)

# %% [markdown]
# ### Prepare and train the model

# %%
model = xgb.XGBRegressor(n_estimators = 1000,\
                        learning_rate = 0.01,\
                        max_depth = 5,\
                        min_split_loss = 10,\
                        min_child_weight = 1,\
                        colsample_bytree = 0.7,\
                        subsample = 0.5,\
                        reg_lambda = 2,\
                        reg_alpha = 0)

#model.fit(X_train_tmp.drop(columns=['Date']),y_train)
model.fit(X_train_tmp,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=10, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=5,
#              min_child_weight=1, min_split_loss=10, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=4,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=2,
#              scale_pos_weight=1, subsample=0.5, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %% [markdown]
# ### Compute extra features for performance evaluation

# %%
y_pred=model.predict(X_test_tmp)

X_test['Pred_diff_next1'] = list(y_pred)
X_test['Pred_diff_next1_rel'] = list(y_pred)
X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1_rel)
# Out:
# <ipython-input-21-86142636e4f0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1'] = list(y_pred)
# <ipython-input-21-86142636e4f0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_rel'] = list(y_pred)
# <ipython-input-21-86142636e4f0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1_rel)

# %% [markdown]
# ### Performance evaluation

# %%
print('==================================================================================')
print('Performance on the relative diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_rel']
pred = X_test['Pred_diff_next1_rel']
print('+++ Relative diff to next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the signed diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_sgn']
pred = X_test['Pred_diff_next1_sgn']
print('+++ Next day BTC price')
print(f"Accuracy:    {accuracy_score(test, pred)}")
# Out:
# ==================================================================================
# Performance on the relative diff between today's and next day's BTC Close price
# +++ Relative diff to next day BTC price
# Explained variance:    2.220446049250313e-16
# R2:                    -0.01599615010776767
# MAE:                   0.021703514819490833
# MSE:                   0.001047076545082776
#
# ==================================================================================
# Performance on the signed diff between today's and next day's BTC Close price
# +++ Next day BTC price
# Accuracy:    0.5671641791044776

# %% [markdown]
# ## Target: Signed difference to the next day's BTC Close price

# %% [markdown]
# ### Prepare training and testing datasets

# %%
# Define target and input variables
target = 'Close_diff_next1_sgn'
variables = df_ana.columns.to_list()

# Split
y = df_ana[target]
X = df_ana[variables]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
#X_test.sort_values(by=['Date'], inplace=True)

# Remove all variables derived from the BTC Close price
skip_pattern = 'Close'

X_train_tmp = X_train[X_train.columns.drop(list(X_train.filter(like=skip_pattern)))].copy(deep=True)
X_train_tmp.drop(columns=['Date'], inplace=True)

X_test_tmp = X_test[X_test.columns.drop(list(X_test.filter(like=skip_pattern)))].copy(deep=True)
X_test_tmp.drop(columns=['Date'], inplace=True)

# %% [markdown]
# ### Prepare and train the model

# %%
imbalance = len(y_train)/sum(y_train)

xgb_model = xgb.XGBClassifier(objective="binary:logistic", n_estimators=20,\
                              random_state=42, eval_metric=["auc"],\
                             #scale_pos_weight=imbalance
                             )
#eval_metric=["auc", "error", "error@0.6"]

#xgb_model.fit(X_train, y_train, eval_set=[(X_test, y_test)])
xgb_model.fit(X_train_tmp, y_train)

y_pred = xgb_model.predict(X_test_tmp)
# Out:
# /Users/snezana/testenv/lib/python3.9/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %% [markdown]
# ### Performance evaluation

# %%
from sklearn.metrics import classification_report,confusion_matrix

print('==================================================================================')
print('Performance on the signed diff between today\'s and next day\'s BTC Close price' )
print()
print('Accuracy:')
print(accuracy_score(y_test,y_pred))
print()
print('Confusion matrix:')
print(confusion_matrix(y_test,y_pred))
print()
print('Classification report:')
print(classification_report(y_test,y_pred))
# Out:
# ==================================================================================
# Performance on the signed diff between today's and next day's BTC Close price
#
# Accuracy:
# 0.582089552238806
#
# Confusion matrix:
# [[12 17]
#  [11 27]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#         -1.0       0.52      0.41      0.46        29
#          1.0       0.61      0.71      0.66        38
#
#     accuracy                           0.58        67
#    macro avg       0.57      0.56      0.56        67
# weighted avg       0.57      0.58      0.57        67
