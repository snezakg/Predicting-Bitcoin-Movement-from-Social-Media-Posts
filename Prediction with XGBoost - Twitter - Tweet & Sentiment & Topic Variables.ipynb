# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sb
import matplotlib.colors as mcolors

import time
from datetime import datetime, timedelta

from sklearn.model_selection import train_test_split
import xgboost as xgb

# Metrics
from sklearn.metrics import explained_variance_score
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn import metrics

# Cross-validation
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_validate

#from sklearn import preprocessing
#from sklearn.pipeline import make_pipeline
from xgboost import XGBRegressor
from xgboost import XGBRFRegressor
#from sklearn.model_selection import GridSearchCV
#from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# # Import prepared dataframes

# %%
# Bitcoin
df_btc = pd.read_csv('df_btc.csv')
df_btc.Date = pd.to_datetime(df_btc.Date)

# Twitter
df_tw = pd.read_csv('df_tw_agg.csv')
df_tw.Date = pd.to_datetime(df_tw.Date)

# %% [markdown]
# # Construct the analysis dataframe

# %% [markdown]
# ### Select the Twitter variables to be used

# %%
variables = ['Date',
 'tw_neg_sum',
 'tw_neg_mean',
 'tw_neg_std',
 'tw_pos_sum',
 'tw_pos_mean',
 'tw_pos_std',
 'tw_comp_sum',
 'tw_comp_mean',
 'tw_comp_std',
 'tw_RelDiffPosNeg_sum',
 'tw_RelDiffPosNeg_mean',
 'tw_RelDiffPosNeg_std',
 'tw_Like_Count_sum',
 'tw_Like_Count_mean',
 'tw_Like_Count_std',
 'tw_Reply_Count_sum',
 'tw_Reply_Count_mean',
 'tw_Reply_Count_std',
 'tw_Retweet_Count_sum',
 'tw_Retweet_Count_mean',
 'tw_Retweet_Count_std',
 'tw_Quote_Count_sum',
 'tw_Quote_Count_mean',
 'tw_Quote_Count_std',
 'tw_comp_q5_count',
 'tw_comp_q4_count',
 'tw_comp_q3_count',
 'tw_comp_q2_count',
 'tw_comp_q1_count',
 'tw_N',
 'tw_N_pos',
 'tw_N_neg',
'tw_topic1_freq',
 'tw_topic2_freq',
 'tw_topic3_freq']

# %% [markdown]
# ### Merge Bitcoin and Twitter dataframes

# %%
# Apply selection on the BTC dataframe
df_ana = df_btc[(df_btc.Date >= pd.to_datetime('01-04-2020', format='%d-%m-%Y')) & \
       (df_btc.Date < pd.to_datetime('15-03-2021', format='%d-%m-%Y'))]
#df_ana = df_ana[['Date', 'Close', 'Close_next1', 'Close_diff_next1', 'Close_diff_next1_rel', 'Close_diff_next1_sgn']]
df_ana = df_ana.dropna()

# Merge with TW dataframe
df_ana = pd.merge(left=df_ana, right=df_tw[variables], how='inner', left_on='Date', right_on='Date')
df_ana.dropna(inplace=True)

# %% [markdown]
# ### Study correlations among features

# %%
corr = df_ana.corr()
plt.figure(figsize = (20,20))
sb.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Target: next day's Bitcoin Close price

# %% [markdown]
# ### Prepare training and testing datasets

# %%
# Define target and input variables
target = 'Close_next1'
variables = df_ana.columns.to_list()

# Split
y = df_ana[target]
X = df_ana[variables]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
#X_test.sort_values(by=['Date'], inplace=True)

# Remove all variables derived from the BTC Close price
skip_pattern = 'Close'

X_train_tmp = X_train[X_train.columns.drop(list(X_train.filter(like=skip_pattern)))].copy(deep=True)
X_train_tmp.drop(columns=['Date'], inplace=True)

X_test_tmp = X_test[X_test.columns.drop(list(X_test.filter(like=skip_pattern)))].copy(deep=True)
X_test_tmp.drop(columns=['Date'], inplace=True)

# %% [markdown]
# ### Prepare and train the model

# %%
model = xgb.XGBRegressor(n_estimators = 1000,\
                        learning_rate = 0.01,\
                        max_depth = 5,\
                        min_split_loss = 10,\
                        min_child_weight = 1,\
                        colsample_bytree = 0.7,\
                        subsample = 0.5,\
                        reg_lambda = 2,\
                        reg_alpha = 0)

#model.fit(X_train_tmp.drop(columns=['Date']),y_train)
model.fit(X_train_tmp,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=10, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=5,
#              min_child_weight=1, min_split_loss=10, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=4,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=2,
#              scale_pos_weight=1, subsample=0.5, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %% [markdown]
# ### Compute extra features for performance evaluation

# %%
y_pred=model.predict(X_test_tmp)
X_test['Pred_next1'] = list(y_pred)
X_test['Pred_diff_next1'] = (X_test.Pred_next1 - X_test.Close).to_list()
X_test['Pred_diff_next1_rel'] = (X_test.Pred_diff_next1/X_test.Close).to_list()
X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1)
# Out:
# <ipython-input-7-e9ddb46e0ea7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_next1'] = list(y_pred)
# <ipython-input-7-e9ddb46e0ea7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1'] = (X_test.Pred_next1 - X_test.Close).to_list()
# <ipython-input-7-e9ddb46e0ea7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_rel'] = (X_test.Pred_diff_next1/X_test.Close).to_list()
# <ipython-input-7-e9ddb46e0ea7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1)

# %% [markdown]
# ### Performance evaluation

# %%
print('==================================================================================')
print('Performance on the target variable: next day\'s BTC Close price' )
test = X_test['Close_next1']
pred = X_test['Pred_next1']
print('+++ Next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the absolute diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1']
pred = X_test['Pred_diff_next1']
print('+++ Diff to next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the relative diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_rel']
pred = X_test['Pred_diff_next1_rel']
print('+++ Relative diff to next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the signed diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_sgn']
pred = X_test['Pred_diff_next1_sgn']
print('+++ Next day BTC price')
print(f"Accuracy:    {accuracy_score(test, pred)}")
# Out:
# ==================================================================================
# Performance on the target variable: next day's BTC Close price
# +++ Next day BTC price
# Explained variance:    0.7943971190690364
# R2:                    0.7941440961785899
# MAE:                   3110.370481573694
# MSE:                   29731154.794223327
#
# ==================================================================================
# Performance on the absolute diff between today's and next day's BTC Close price
# +++ Diff to next day BTC price
# Explained variance:    -36.13863084006167
# R2:                    -36.18433508155785
# MAE:                   3110.370481573694
# MSE:                   29731154.794223327
#
# ==================================================================================
# Performance on the relative diff between today's and next day's BTC Close price
# +++ Relative diff to next day BTC price
# Explained variance:    -55.15328865036754
# R2:                    -953.6723809201255
# MAE:                   0.9636502139624824
# MSE:                   0.9838768170467601
#
# ==================================================================================
# Performance on the signed diff between today's and next day's BTC Close price
# +++ Next day BTC price
# Accuracy:    0.43283582089552236

# %% [markdown]
# ### Plot predictions

# %%
# Next day's BTC price

X_test.sort_values(by=['Date'], inplace=True)
x = X_test.Date
y_test = X_test['Close_next1']
y_pred = X_test['Pred_next1']

fig, ax = plt.subplots(figsize=(15, 5))

ax.set_xlabel('Date')
ax.set_ylabel('Next day BTC price')
ax.plot(x, y_test, color='tab:red', label='Ground Truth')
ax.plot(x, y_pred, color='tab:blue', label='Prediction')

plt.legend()
#ax1.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
# Out:
# <ipython-input-9-c9312ce135ef>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.sort_values(by=['Date'], inplace=True)

# %%
# Absolute diff to next day's BTC price

x = X_test.Date
y_test = X_test['Close_diff_next1']
y_pred = X_test['Pred_diff_next1']

fig, ax = plt.subplots(figsize=(15, 5))

ax.set_xlabel('Date')
ax.set_ylabel('Absolute diff to next day\'s BTC price')
ax.plot(x, y_test, color='tab:red', label='Ground Truth')
ax.plot(x, y_pred, color='tab:blue', label='Prediction')

plt.legend()
#ax1.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
# Relative diff to next day's BTC price

x = X_test.Date
y_test = X_test['Close_diff_next1_rel']
y_pred = X_test['Pred_diff_next1_rel']

fig, ax = plt.subplots(figsize=(15, 5))

ax.set_xlabel('Date')
ax.set_ylabel('Relative diff to next day\'s BTC price')
ax.plot(x, y_test, color='tab:red', label='Ground Truth')
ax.plot(x, y_pred, color='tab:blue', label='Prediction')

plt.legend()
#ax1.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
# Signed diff to next day's BTC price

x = X_test.Date
y_test = X_test['Close_diff_next1_sgn']
y_pred = X_test['Pred_diff_next1_sgn']

fig, ax = plt.subplots(figsize=(15, 5))

ax.set_xlabel('Date')
ax.set_ylabel('Relative diff to next day\'s BTC price')
ax.plot(x, y_test, color='tab:red', label='Ground Truth')
ax.plot(x, y_pred, color='tab:blue', label='Prediction')

plt.legend()
#ax1.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %% [markdown]
# ### Feature importance

# %%
import operator

for importance_type in ['weight', 'gain', 'cover']:

    # Get the importance dictionary (by gain) from the booster
    importance = model.get_booster().get_score(importance_type=importance_type)

    # make your changes
    for key in importance.keys():
        importance[key] = round(importance[key],2)
        
    print('==============')
    print(f'Importance type: {importance_type}')
    print(dict(sorted(importance.items(),
                            key=operator.itemgetter(1),
                            reverse=True)))

    # provide the importance dictionary to the plotting function
    #ax = plot_importance(importance, max_num_features=3, importance_type='gain', show_values=True)

    # Plot variable importance
    ax = xgb.plot_importance(importance, max_num_features=10, grid=False, xlabel=None,\
                             title='Feature importance according to '+importance_type)
    fig = ax.figure
    fig.set_size_inches(10, 10)
# Out:
# ==============
# Importance type: weight
# {'tw_neg_sum': 1837, 'tw_neg_mean': 981, 'tw_neg_std': 708, 'tw_pos_std': 627, 'tw_pos_sum': 602, 'tw_Like_Count_mean': 577, 'tw_pos_mean': 547, 'tw_Like_Count_sum': 512, 'tw_Retweet_Count_mean': 464, 'tw_comp_sum': 459, 'tw_comp_q3_count': 454, 'tw_Reply_Count_mean': 447, 'tw_Quote_Count_sum': 447, 'tw_Like_Count_std': 438, 'tw_RelDiffPosNeg_sum': 436, 'tw_RelDiffPosNeg_std': 434, 'tw_topic1_freq': 430, 'tw_topic2_freq': 428, 'tw_topic3_freq': 424, 'tw_comp_std': 390, 'tw_Quote_Count_mean': 376, 'tw_Reply_Count_sum': 345, 'tw_Retweet_Count_sum': 335, 'tw_Retweet_Count_std': 326, 'tw_comp_q4_count': 320, 'tw_comp_mean': 311, 'tw_comp_q2_count': 291, 'tw_comp_q5_count': 291, 'tw_Reply_Count_std': 275, 'tw_Quote_Count_std': 251, 'tw_RelDiffPosNeg_mean': 230, 'tw_comp_q1_count': 203, 'tw_N_pos': 162, 'tw_N_neg': 159, 'tw_N': 154}
# ==============
# Importance type: gain
# {'tw_Like_Count_sum': 951679651.93, 'tw_comp_q1_count': 826597050.29, 'tw_N': 425483499.06, 'tw_N_pos': 360838076.82, 'tw_N_neg': 296800271.97, 'tw_comp_q4_count': 208911586.16, 'tw_RelDiffPosNeg_sum': 187093459.61, 'tw_comp_q3_count': 148894610.44, 'tw_pos_sum': 83739629.71, 'tw_Retweet_Count_sum': 76799112.27, 'tw_topic3_freq': 76397761.45, 'tw_Like_Count_mean': 54089950.95, 'tw_comp_q2_count': 45650416.75, 'tw_topic1_freq': 39089960.74, 'tw_Retweet_Count_mean': 31673889.0, 'tw_comp_sum': 30234425.74, 'tw_Reply_Count_sum': 29829622.52, 'tw_neg_sum': 29332883.67, 'tw_topic2_freq': 28859027.81, 'tw_Like_Count_std': 27435738.36, 'tw_pos_std': 24407525.69, 'tw_Quote_Count_mean': 24294891.35, 'tw_Reply_Count_mean': 22890834.18, 'tw_comp_q5_count': 20412089.67, 'tw_Quote_Count_sum': 19626456.28, 'tw_neg_std': 18553021.81, 'tw_RelDiffPosNeg_std': 18523758.19, 'tw_Reply_Count_std': 15814880.87, 'tw_Quote_Count_std': 13633940.98, 'tw_comp_mean': 13632050.08, 'tw_neg_mean': 13334570.89, 'tw_RelDiffPosNeg_mean': 12064787.06, 'tw_pos_mean': 10666351.59, 'tw_Retweet_Count_std': 9924088.75, 'tw_comp_std': 9322270.15}
# ==============
# Importance type: cover
# {'tw_N_pos': 85.75, 'tw_N': 84.74, 'tw_Like_Count_sum': 83.64, 'tw_Retweet_Count_sum': 73.45, 'tw_RelDiffPosNeg_sum': 72.11, 'tw_comp_q3_count': 70.2, 'tw_N_neg': 67.26, 'tw_comp_q1_count': 65.84, 'tw_comp_q2_count': 61.19, 'tw_comp_q4_count': 59.29, 'tw_Like_Count_mean': 52.84, 'tw_Quote_Count_sum': 51.18, 'tw_comp_q5_count': 47.54, 'tw_comp_sum': 47.0, 'tw_Like_Count_std': 45.75, 'tw_Quote_Count_std': 43.24, 'tw_Retweet_Count_mean': 43.18, 'tw_Retweet_Count_std': 41.1, 'tw_Reply_Count_sum': 39.55, 'tw_topic2_freq': 38.63, 'tw_RelDiffPosNeg_mean': 38.3, 'tw_Quote_Count_mean': 37.46, 'tw_RelDiffPosNeg_std': 36.0, 'tw_Reply_Count_std': 34.53, 'tw_topic3_freq': 34.45, 'tw_pos_sum': 33.19, 'tw_comp_mean': 32.47, 'tw_Reply_Count_mean': 31.22, 'tw_topic1_freq': 30.16, 'tw_pos_std': 26.69, 'tw_comp_std': 25.44, 'tw_pos_mean': 24.66, 'tw_neg_std': 19.24, 'tw_neg_sum': 17.83, 'tw_neg_mean': 16.64}

# %% [markdown]
# ## Target: Absolute difference to the next day's BTC Close price

# %% [markdown]
# ### Prepare training and testing datasets

# %%
# Define target and input variables
target = 'Close_diff_next1'
variables = df_ana.columns.to_list()

# Split
y = df_ana[target]
X = df_ana[variables]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Remove all variables derived from the BTC Close price
skip_pattern = 'Close'

X_train_tmp = X_train[X_train.columns.drop(list(X_train.filter(like=skip_pattern)))].copy(deep=True)
X_train_tmp.drop(columns=['Date'], inplace=True)

X_test_tmp = X_test[X_test.columns.drop(list(X_test.filter(like=skip_pattern)))].copy(deep=True)
X_test_tmp.drop(columns=['Date'], inplace=True)

# %% [markdown]
# ### Prepare and train the model

# %%
model = xgb.XGBRegressor(n_estimators = 1000,\
                        learning_rate = 0.01,\
                        max_depth = 5,\
                        min_split_loss = 10,\
                        min_child_weight = 1,\
                        colsample_bytree = 0.7,\
                        subsample = 0.5,\
                        reg_lambda = 2,\
                        reg_alpha = 0)

#model.fit(X_train_tmp.drop(columns=['Date']),y_train)
model.fit(X_train_tmp,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=10, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=5,
#              min_child_weight=1, min_split_loss=10, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=4,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=2,
#              scale_pos_weight=1, subsample=0.5, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %% [markdown]
# ### Compute extra features for performance evaluation

# %%
y_pred=model.predict(X_test_tmp)

X_test['Pred_diff_next1'] = list(y_pred)
X_test['Pred_diff_next1_rel'] = (X_test.Pred_diff_next1/X_test.Close).to_list()
X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1)
# Out:
# <ipython-input-16-b6d71e7a9ad9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1'] = list(y_pred)
# <ipython-input-16-b6d71e7a9ad9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_rel'] = (X_test.Pred_diff_next1/X_test.Close).to_list()
# <ipython-input-16-b6d71e7a9ad9>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1)

# %% [markdown]
# ### Performance evaluation

# %%
print('==================================================================================')
print('Performance on the absolute diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1']
pred = X_test['Pred_diff_next1']
print('+++ Diff to next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the relative diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_rel']
pred = X_test['Pred_diff_next1_rel']
print('+++ Relative diff to next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the signed diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_sgn']
pred = X_test['Pred_diff_next1_sgn']
print('+++ Next day BTC price')
print(f"Accuracy:    {accuracy_score(test, pred)}")
# Out:
# ==================================================================================
# Performance on the absolute diff between today's and next day's BTC Close price
# +++ Diff to next day BTC price
# Explained variance:    -0.7523572917909218
# R2:                    -0.7958960144814284
# MAE:                   639.3325538123431
# MSE:                   1435928.9276993878
#
# ==================================================================================
# Performance on the relative diff between today's and next day's BTC Close price
# +++ Relative diff to next day BTC price
# Explained variance:    -0.6792522340058049
# R2:                    -958.7453154648193
# MAE:                   0.9936671050621351
# MSE:                   0.9891049380154525
#
# ==================================================================================
# Performance on the signed diff between today's and next day's BTC Close price
# +++ Next day BTC price
# Accuracy:    0.5522388059701493

# %%
import operator

for importance_type in ['weight', 'gain', 'cover']:

    # Get the importance dictionary (by gain) from the booster
    importance = model.get_booster().get_score(importance_type=importance_type)

    # make your changes
    for key in importance.keys():
        importance[key] = round(importance[key],2)
        
    print('==============')
    print(f'Importance type: {importance_type}')
    print(dict(sorted(importance.items(),
                            key=operator.itemgetter(1),
                            reverse=True)))

    # provide the importance dictionary to the plotting function
    #ax = plot_importance(importance, max_num_features=3, importance_type='gain', show_values=True)

    # Plot variable importance
    ax = xgb.plot_importance(importance, max_num_features=10, grid=False, xlabel=None,\
                             title='Feature importance according to '+importance_type)
    fig = ax.figure
    fig.set_size_inches(10, 10)
# Out:
# ==============
# Importance type: weight
# {'tw_neg_sum': 2249, 'tw_neg_mean': 1228, 'tw_neg_std': 1019, 'tw_pos_sum': 741, 'tw_pos_mean': 719, 'tw_pos_std': 682, 'tw_RelDiffPosNeg_std': 649, 'tw_comp_std': 624, 'tw_Like_Count_mean': 580, 'tw_comp_mean': 552, 'tw_comp_sum': 503, 'tw_topic1_freq': 496, 'tw_comp_q4_count': 453, 'tw_Reply_Count_mean': 420, 'tw_Like_Count_std': 412, 'tw_comp_q3_count': 409, 'tw_Retweet_Count_mean': 405, 'tw_Quote_Count_mean': 405, 'tw_topic2_freq': 404, 'tw_RelDiffPosNeg_sum': 394, 'tw_Reply_Count_sum': 374, 'tw_Like_Count_sum': 371, 'tw_Reply_Count_std': 356, 'tw_RelDiffPosNeg_mean': 339, 'tw_Retweet_Count_std': 337, 'tw_comp_q5_count': 332, 'tw_comp_q1_count': 318, 'tw_Quote_Count_sum': 313, 'tw_topic3_freq': 309, 'tw_Quote_Count_std': 307, 'tw_Retweet_Count_sum': 295, 'tw_N_neg': 275, 'tw_comp_q2_count': 261, 'tw_N': 167, 'tw_N_pos': 123}
# ==============
# Importance type: gain
# {'tw_comp_q4_count': 2825447.86, 'tw_N_neg': 2342165.51, 'tw_N': 2323303.02, 'tw_N_pos': 1988424.52, 'tw_comp_q1_count': 1900205.92, 'tw_comp_q2_count': 1725774.93, 'tw_comp_q5_count': 1705326.17, 'tw_Like_Count_sum': 1692362.44, 'tw_comp_q3_count': 1677524.68, 'tw_RelDiffPosNeg_sum': 1546947.74, 'tw_comp_sum': 1186002.21, 'tw_comp_mean': 1180558.18, 'tw_pos_sum': 1163566.49, 'tw_comp_std': 1038595.77, 'tw_Reply_Count_sum': 975187.66, 'tw_pos_std': 972933.06, 'tw_Like_Count_mean': 965075.49, 'tw_RelDiffPosNeg_std': 962208.73, 'tw_Retweet_Count_sum': 941056.55, 'tw_Like_Count_std': 916370.3, 'tw_Quote_Count_mean': 906056.36, 'tw_Retweet_Count_std': 875014.85, 'tw_RelDiffPosNeg_mean': 868390.13, 'tw_pos_mean': 729136.44, 'tw_Reply_Count_mean': 727765.94, 'tw_topic1_freq': 693520.69, 'tw_topic2_freq': 690145.37, 'tw_Quote_Count_std': 675400.13, 'tw_Quote_Count_sum': 673780.67, 'tw_Reply_Count_std': 624162.5, 'tw_neg_sum': 539476.62, 'tw_neg_std': 534655.71, 'tw_topic3_freq': 525214.55, 'tw_Retweet_Count_mean': 512581.09, 'tw_neg_mean': 362052.62}
# ==============
# Importance type: cover
# {'tw_comp_q4_count': 82.28, 'tw_N_pos': 76.8, 'tw_N_neg': 76.17, 'tw_N': 74.3, 'tw_comp_q1_count': 70.87, 'tw_comp_q3_count': 68.99, 'tw_comp_q2_count': 63.04, 'tw_comp_q5_count': 60.3, 'tw_Like_Count_sum': 53.64, 'tw_Like_Count_mean': 52.34, 'tw_comp_mean': 49.81, 'tw_topic1_freq': 49.53, 'tw_RelDiffPosNeg_sum': 45.4, 'tw_RelDiffPosNeg_mean': 43.95, 'tw_RelDiffPosNeg_std': 43.42, 'tw_Retweet_Count_sum': 41.94, 'tw_Reply_Count_std': 41.22, 'tw_Retweet_Count_mean': 41.11, 'tw_Reply_Count_sum': 40.29, 'tw_topic2_freq': 39.4, 'tw_Like_Count_std': 37.86, 'tw_topic3_freq': 36.97, 'tw_Quote_Count_std': 33.45, 'tw_Quote_Count_mean': 32.24, 'tw_Reply_Count_mean': 30.7, 'tw_pos_sum': 30.59, 'tw_comp_sum': 29.5, 'tw_Retweet_Count_std': 28.15, 'tw_Quote_Count_sum': 27.6, 'tw_pos_mean': 24.81, 'tw_pos_std': 24.15, 'tw_comp_std': 23.9, 'tw_neg_std': 22.12, 'tw_neg_sum': 15.73, 'tw_neg_mean': 15.02}

# %% [markdown]
# ## Target: Relative difference to the next day's BTC Close price

# %% [markdown]
# ### Prepare training and testing datasets

# %%
# Define target and input variables
target = 'Close_diff_next1_rel'
variables = df_ana.columns.to_list()

# Split
y = df_ana[target]
X = df_ana[variables]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Remove all variables derived from the BTC Close price
skip_pattern = 'Close'

X_train_tmp = X_train[X_train.columns.drop(list(X_train.filter(like=skip_pattern)))].copy(deep=True)
X_train_tmp.drop(columns=['Date'], inplace=True)

X_test_tmp = X_test[X_test.columns.drop(list(X_test.filter(like=skip_pattern)))].copy(deep=True)
X_test_tmp.drop(columns=['Date'], inplace=True)

# %% [markdown]
# ### Prepare and train the model

# %%
model = xgb.XGBRegressor(n_estimators = 1000,\
                        learning_rate = 0.01,\
                        max_depth = 5,\
                        min_split_loss = 10,\
                        min_child_weight = 1,\
                        colsample_bytree = 0.7,\
                        subsample = 0.5,\
                        reg_lambda = 2,\
                        reg_alpha = 0)

#model.fit(X_train_tmp.drop(columns=['Date']),y_train)
model.fit(X_train_tmp,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=10, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=5,
#              min_child_weight=1, min_split_loss=10, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=4,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=2,
#              scale_pos_weight=1, subsample=0.5, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %% [markdown]
# ### Compute extra features for performance evaluation

# %%
y_pred=model.predict(X_test_tmp)

X_test['Pred_diff_next1'] = list(y_pred)
X_test['Pred_diff_next1_rel'] = list(y_pred)
X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1_rel)
# Out:
# <ipython-input-21-86142636e4f0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1'] = list(y_pred)
# <ipython-input-21-86142636e4f0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_rel'] = list(y_pred)
# <ipython-input-21-86142636e4f0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1_rel)

# %% [markdown]
# ### Performance evaluation

# %%
print('==================================================================================')
print('Performance on the relative diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_rel']
pred = X_test['Pred_diff_next1_rel']
print('+++ Relative diff to next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the signed diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_sgn']
pred = X_test['Pred_diff_next1_sgn']
print('+++ Next day BTC price')
print(f"Accuracy:    {accuracy_score(test, pred)}")
# Out:
# ==================================================================================
# Performance on the relative diff between today's and next day's BTC Close price
# +++ Relative diff to next day BTC price
# Explained variance:    2.220446049250313e-16
# R2:                    -0.01599615010776767
# MAE:                   0.021703514819490833
# MSE:                   0.001047076545082776
#
# ==================================================================================
# Performance on the signed diff between today's and next day's BTC Close price
# +++ Next day BTC price
# Accuracy:    0.5671641791044776

# %% [markdown]
# ## Target: Signed difference to the next day's BTC Close price

# %% [markdown]
# ### Prepare training and testing datasets

# %%
# Define target and input variables
target = 'Close_diff_next1_sgn'
variables = df_ana.columns.to_list()

# Split
y = df_ana[target]
X = df_ana[variables]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
#X_test.sort_values(by=['Date'], inplace=True)

# Remove all variables derived from the BTC Close price
skip_pattern = 'Close'

X_train_tmp = X_train[X_train.columns.drop(list(X_train.filter(like=skip_pattern)))].copy(deep=True)
X_train_tmp.drop(columns=['Date'], inplace=True)

X_test_tmp = X_test[X_test.columns.drop(list(X_test.filter(like=skip_pattern)))].copy(deep=True)
X_test_tmp.drop(columns=['Date'], inplace=True)

# %% [markdown]
# ### Prepare and train the model

# %%
imbalance = len(y_train)/sum(y_train)

xgb_model = xgb.XGBClassifier(objective="binary:logistic", n_estimators=20,\
                              random_state=42, eval_metric=["auc"],\
                             #scale_pos_weight=imbalance
                             )
#eval_metric=["auc", "error", "error@0.6"]

#xgb_model.fit(X_train, y_train, eval_set=[(X_test, y_test)])
xgb_model.fit(X_train_tmp, y_train)

y_pred = xgb_model.predict(X_test_tmp)
# Out:
# /Users/snezana/testenv/lib/python3.9/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %% [markdown]
# ### Performance evaluation

# %%
from sklearn.metrics import classification_report,confusion_matrix

print('==================================================================================')
print('Performance on the signed diff between today\'s and next day\'s BTC Close price' )
print()
print('Accuracy:')
print(accuracy_score(y_test,y_pred))
print()
print('Confusion matrix:')
print(confusion_matrix(y_test,y_pred))
print()
print('Classification report:')
print(classification_report(y_test,y_pred))
# Out:
# ==================================================================================
# Performance on the signed diff between today's and next day's BTC Close price
#
# Accuracy:
# 0.5671641791044776
#
# Confusion matrix:
# [[12 17]
#  [12 26]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#         -1.0       0.50      0.41      0.45        29
#          1.0       0.60      0.68      0.64        38
#
#     accuracy                           0.57        67
#    macro avg       0.55      0.55      0.55        67
# weighted avg       0.56      0.57      0.56        67
