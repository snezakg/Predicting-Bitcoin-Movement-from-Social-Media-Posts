# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sb
import matplotlib.colors as mcolors

import time
from datetime import datetime, timedelta

from sklearn.model_selection import train_test_split
import xgboost as xgb

# Metrics
from sklearn.metrics import explained_variance_score
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn import metrics

# Cross-validation
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_validate

#from sklearn import preprocessing
#from sklearn.pipeline import make_pipeline
from xgboost import XGBRegressor
from xgboost import XGBRFRegressor
#from sklearn.model_selection import GridSearchCV
#from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# # Import prepared dataframes

# %%
# Bitcoin
df_btc = pd.read_csv('df_btc.csv')
df_btc.Date = pd.to_datetime(df_btc.Date)

# Twitter
df_tw = pd.read_csv('df_tw_agg.csv')
df_tw.Date = pd.to_datetime(df_tw.Date)

# %% [markdown]
# # Construct the analysis dataframe

# %% [markdown]
# ### Select the Twitter variables to be used

# %%
variables = list(df_tw.columns)

# %% [markdown]
# ### Merge Bitcoin and Twitter dataframes

# %%
# Apply selection on the BTC dataframe
df_ana = df_btc[(df_btc.Date >= pd.to_datetime('01-04-2020', format='%d-%m-%Y')) & \
       (df_btc.Date < pd.to_datetime('15-03-2021', format='%d-%m-%Y'))]
#df_ana = df_ana[['Date', 'Close', 'Close_next1', 'Close_diff_next1', 'Close_diff_next1_rel', 'Close_diff_next1_sgn']]
df_ana = df_ana.dropna()

# Merge with TW dataframe
df_ana = pd.merge(left=df_ana, right=df_tw[variables], how='inner', left_on='Date', right_on='Date')
df_ana.dropna(inplace=True)

# %% [markdown]
# ### Study correlations among features

# %%
corr = df_ana.corr()
plt.figure(figsize = (20,20))
sb.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Target: next day's Bitcoin Close price

# %% [markdown]
# ### Prepare training and testing datasets

# %%
# Define target and input variables
target = 'Close_next1'
variables = df_ana.columns.to_list()

# Split
y = df_ana[target]
X = df_ana[variables]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
#X_test.sort_values(by=['Date'], inplace=True)

# Remove all variables derived from the BTC Close price
skip_pattern = 'Close'

X_train_tmp = X_train[X_train.columns.drop(list(X_train.filter(like=skip_pattern)))].copy(deep=True)
X_train_tmp.drop(columns=['Date'], inplace=True)

X_test_tmp = X_test[X_test.columns.drop(list(X_test.filter(like=skip_pattern)))].copy(deep=True)
X_test_tmp.drop(columns=['Date'], inplace=True)

# %% [markdown]
# ### Prepare and train the model

# %%
model = xgb.XGBRegressor(n_estimators = 1000,\
                        learning_rate = 0.01,\
                        max_depth = 5,\
                        min_split_loss = 10,\
                        min_child_weight = 1,\
                        colsample_bytree = 0.7,\
                        subsample = 0.5,\
                        reg_lambda = 2,\
                        reg_alpha = 0)

#model.fit(X_train_tmp.drop(columns=['Date']),y_train)
model.fit(X_train_tmp,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=10, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=5,
#              min_child_weight=1, min_split_loss=10, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=4,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=2,
#              scale_pos_weight=1, subsample=0.5, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %% [markdown]
# ### Compute extra features for performance evaluation

# %%
y_pred=model.predict(X_test_tmp)
X_test['Pred_next1'] = list(y_pred)
X_test['Pred_diff_next1'] = (X_test.Pred_next1 - X_test.Close).to_list()
X_test['Pred_diff_next1_rel'] = (X_test.Pred_diff_next1/X_test.Close).to_list()
X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1)
# Out:
# <ipython-input-7-e9ddb46e0ea7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_next1'] = list(y_pred)
# <ipython-input-7-e9ddb46e0ea7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1'] = (X_test.Pred_next1 - X_test.Close).to_list()
# <ipython-input-7-e9ddb46e0ea7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_rel'] = (X_test.Pred_diff_next1/X_test.Close).to_list()
# <ipython-input-7-e9ddb46e0ea7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1)

# %% [markdown]
# ### Performance evaluation

# %%
print('==================================================================================')
print('Performance on the target variable: next day\'s BTC Close price' )
test = X_test['Close_next1']
pred = X_test['Pred_next1']
print('+++ Next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the absolute diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1']
pred = X_test['Pred_diff_next1']
print('+++ Diff to next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the relative diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_rel']
pred = X_test['Pred_diff_next1_rel']
print('+++ Relative diff to next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the signed diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_sgn']
pred = X_test['Pred_diff_next1_sgn']
print('+++ Next day BTC price')
print(f"Accuracy:    {accuracy_score(test, pred)}")
# Out:
# ==================================================================================
# Performance on the target variable: next day's BTC Close price
# +++ Next day BTC price
# Explained variance:    0.9761966295436486
# R2:                    0.9761452213274823
# MAE:                   1054.3936712779853
# MSE:                   3445274.6029079263
#
# ==================================================================================
# Performance on the absolute diff between today's and next day's BTC Close price
# +++ Diff to next day BTC price
# Explained variance:    -3.299670238689398
# R2:                    -3.308956250411131
# MAE:                   1054.3936712779853
# MSE:                   3445274.6029079263
#
# ==================================================================================
# Performance on the relative diff between today's and next day's BTC Close price
# +++ Relative diff to next day BTC price
# Explained variance:    -2.9950939209799468
# R2:                    -980.1640172844008
# MAE:                   1.00352456495915
# MSE:                   1.0111788605387086
#
# ==================================================================================
# Performance on the signed diff between today's and next day's BTC Close price
# +++ Next day BTC price
# Accuracy:    0.417910447761194

# %% [markdown]
# ### Plot predictions

# %%
# Next day's BTC price

X_test.sort_values(by=['Date'], inplace=True)
x = X_test.Date
y_test = X_test['Close_next1']
y_pred = X_test['Pred_next1']

fig, ax = plt.subplots(figsize=(15, 5))

ax.set_xlabel('Date')
ax.set_ylabel('Next day BTC price')
ax.plot(x, y_test, color='tab:red', label='Ground Truth')
ax.plot(x, y_pred, color='tab:blue', label='Prediction')

plt.legend()
#ax1.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
# Out:
# <ipython-input-9-c9312ce135ef>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.sort_values(by=['Date'], inplace=True)

# %%
# Absolute diff to next day's BTC price

x = X_test.Date
y_test = X_test['Close_diff_next1']
y_pred = X_test['Pred_diff_next1']

fig, ax = plt.subplots(figsize=(15, 5))

ax.set_xlabel('Date')
ax.set_ylabel('Absolute diff to next day\'s BTC price')
ax.plot(x, y_test, color='tab:red', label='Ground Truth')
ax.plot(x, y_pred, color='tab:blue', label='Prediction')

plt.legend()
#ax1.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
# Relative diff to next day's BTC price

x = X_test.Date
y_test = X_test['Close_diff_next1_rel']
y_pred = X_test['Pred_diff_next1_rel']

fig, ax = plt.subplots(figsize=(15, 5))

ax.set_xlabel('Date')
ax.set_ylabel('Relative diff to next day\'s BTC price')
ax.plot(x, y_test, color='tab:red', label='Ground Truth')
ax.plot(x, y_pred, color='tab:blue', label='Prediction')

plt.legend()
#ax1.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
# Signed diff to next day's BTC price

x = X_test.Date
y_test = X_test['Close_diff_next1_sgn']
y_pred = X_test['Pred_diff_next1_sgn']

fig, ax = plt.subplots(figsize=(15, 5))

ax.set_xlabel('Date')
ax.set_ylabel('Relative diff to next day\'s BTC price')
ax.plot(x, y_test, color='tab:red', label='Ground Truth')
ax.plot(x, y_pred, color='tab:blue', label='Prediction')

plt.legend()
#ax1.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %% [markdown]
# ### Feature importance

# %%
import operator

for importance_type in ['weight', 'gain', 'cover']:

    # Get the importance dictionary (by gain) from the booster
    importance = model.get_booster().get_score(importance_type=importance_type)

    # make your changes
    for key in importance.keys():
        importance[key] = round(importance[key],2)
        
    print('==============')
    print(f'Importance type: {importance_type}')
    print(dict(sorted(importance.items(),
                            key=operator.itemgetter(1),
                            reverse=True)))

    # provide the importance dictionary to the plotting function
    #ax = plot_importance(importance, max_num_features=3, importance_type='gain', show_values=True)

    # Plot variable importance
    ax = xgb.plot_importance(importance, max_num_features=10, grid=False, xlabel=None,\
                             title='Feature importance according to '+importance_type)
    fig = ax.figure
    fig.set_size_inches(10, 10)
# Out:
# ==============
# Importance type: weight
# {'tw_neg_sum': 1014, 'tw_neg_mean': 668, 'tw_neg_std': 450, 'tw_pos_std': 379, 'tw_pos_mean': 374, 'tw_pos_sum': 341, 'tw_Retweet_Count_sum_last10_mean': 314, 'tw_Like_Count_mean': 276, 'tw_Reply_Count_mean': 256, 'tw_topic2_freq': 251, 'tw_comp_sum': 240, 'tw_neg_sum_last10_mean': 235, 'tw_Like_Count_sum': 232, 'tw_comp_std': 232, 'tw_comp_sum_last10_std': 231, 'tw_RelDiffPosNeg_sum_last10_mean': 224, 'tw_topic1_freq': 211, 'tw_topic3_freq': 210, 'tw_Quote_Count_sum_last10_std': 209, 'tw_Retweet_Count_mean': 205, 'tw_Reply_Count_sum_last10_std': 205, 'tw_pos_sum_last10_mean': 203, 'tw_RelDiffPosNeg_std': 202, 'tw_neg_sum_last10_std': 197, 'tw_pos_sum_last10_std': 196, 'tw_Reply_Count_sum_last5_std': 193, 'tw_Quote_Count_sum_last10_mean': 192, 'tw_comp_mean': 190, 'tw_comp_sum_last10_mean': 187, 'tw_RelDiffPosNeg_sum': 183, 'tw_Like_Count_std': 181, 'tw_neg_sum_last5_std': 180, 'tw_comp_sum_last5_std': 169, 'tw_Quote_Count_sum_last5_std': 162, 'tw_N_neg_last10_std': 161, 'tw_Reply_Count_sum': 158, 'tw_Reply_Count_sum_last5_mean': 151, 'tw_Quote_Count_mean': 150, 'tw_RelDiffPosNeg_sum_last5_std': 150, 'tw_Retweet_Count_sum_last10_std': 148, 'tw_pos_sum_last5_std': 148, 'tw_Retweet_Count_std': 144, 'tw_Retweet_Count_sum': 144, 'tw_comp_q4_count': 139, 'tw_RelDiffPosNeg_mean': 138, 'tw_neg_sum_last5_mean': 137, 'tw_RelDiffPosNeg_sum_last10_std': 136, 'tw_Like_Count_sum_last10_std': 136, 'tw_Like_Count_sum_last10_mean': 133, 'tw_Quote_Count_sum_last5_mean': 133, 'tw_Quote_Count_std': 124, 'tw_Reply_Count_std': 121, 'tw_pos_sum_last5_mean': 120, 'tw_comp_sum_last5_mean': 117, 'tw_comp_q5_count': 116, 'tw_comp_q2_count': 115, 'tw_Reply_Count_sum_last10_mean': 115, 'tw_Retweet_Count_sum_last5_std': 114, 'tw_N_last10_mean': 111, 'tw_RelDiffPosNeg_sum_last5_mean': 111, 'tw_Like_Count_sum_last5_std': 110, 'tw_comp_q3_count': 110, 'tw_Retweet_Count_sum_last5_mean': 104, 'tw_N_pos_last5_mean': 103, 'tw_Quote_Count_sum': 101, 'tw_N_neg_last5_std': 88, 'tw_N_neg_last10_mean': 79, 'tw_N_neg': 74, 'tw_comp_q1_count': 63, 'tw_N_pos_last5_std': 61, 'tw_Like_Count_sum_last5_mean': 59, 'tw_N_last5_mean': 58, 'tw_N_neg_last5_mean': 58, 'tw_N_pos_last10_mean': 57, 'tw_N_last10_std': 49, 'tw_N_pos_last10_std': 46, 'tw_N_last5_std': 45, 'tw_N': 28, 'tw_N_pos': 26, 'elonmusk': 13, 'MrBeast': 1}
# ==============
# Importance type: gain
# {'tw_N_neg_last10_mean': 3110325292.38, 'tw_neg_sum_last10_mean': 1903308017.88, 'tw_N_last5_mean': 961295955.49, 'tw_N_pos_last5_mean': 802306632.03, 'tw_pos_sum_last10_mean': 674940428.9, 'tw_Like_Count_sum_last10_mean': 364575810.48, 'tw_pos_sum_last5_mean': 295326795.64, 'tw_Retweet_Count_sum_last10_mean': 261816171.93, 'tw_N_neg_last5_mean': 172706262.74, 'tw_neg_sum_last5_mean': 164390070.73, 'tw_Retweet_Count_sum_last5_mean': 107461748.75, 'tw_RelDiffPosNeg_sum_last10_mean': 92651390.09, 'tw_N_last10_mean': 89221363.97, 'tw_N_pos_last10_mean': 88403010.3, 'tw_comp_sum_last10_mean': 66813443.04, 'tw_comp_sum_last5_mean': 48571444.53, 'tw_RelDiffPosNeg_sum_last5_mean': 36370630.11, 'tw_RelDiffPosNeg_sum': 27628545.19, 'tw_N_neg_last10_std': 26204682.3, 'tw_Retweet_Count_sum': 23463050.06, 'tw_neg_sum_last10_std': 21433782.13, 'tw_Like_Count_sum_last5_mean': 18800735.87, 'tw_Like_Count_sum': 17075345.84, 'tw_Reply_Count_sum_last10_mean': 15437305.94, 'tw_N_neg_last5_std': 13741411.63, 'tw_N_pos': 8739988.34, 'tw_comp_q4_count': 8703324.77, 'tw_comp_q3_count': 7937856.55, 'tw_N': 7501504.41, 'tw_N_neg': 6715955.76, 'tw_comp_q1_count': 6238398.71, 'tw_RelDiffPosNeg_mean': 5710081.11, 'tw_RelDiffPosNeg_sum_last10_std': 5282345.15, 'tw_Reply_Count_sum_last5_std': 4989727.07, 'tw_neg_sum_last5_std': 4634203.88, 'tw_comp_q5_count': 4118019.36, 'tw_Retweet_Count_mean': 4113515.75, 'tw_comp_sum_last5_std': 3952637.31, 'tw_N_pos_last10_std': 3891398.81, 'tw_comp_q2_count': 3886125.18, 'tw_pos_sum_last5_std': 3720613.71, 'tw_Reply_Count_sum_last10_std': 3584560.47, 'tw_Retweet_Count_sum_last10_std': 3425657.46, 'tw_comp_sum': 3385464.66, 'tw_Like_Count_std': 3356816.85, 'tw_Like_Count_sum_last10_std': 3337104.52, 'tw_Like_Count_mean': 3169836.37, 'elonmusk': 3106267.16, 'tw_topic3_freq': 3047886.42, 'tw_RelDiffPosNeg_std': 2950372.02, 'tw_pos_sum': 2836075.63, 'tw_N_last10_std': 2726211.98, 'tw_Quote_Count_sum_last5_std': 2723782.82, 'tw_Quote_Count_sum_last10_mean': 2708395.49, 'tw_Quote_Count_sum_last10_std': 2701696.34, 'tw_comp_std': 2650692.76, 'tw_Quote_Count_mean': 2640154.29, 'tw_pos_sum_last10_std': 2584517.13, 'tw_Quote_Count_sum_last5_mean': 2505582.79, 'tw_Reply_Count_sum_last5_mean': 2496460.68, 'tw_N_last5_std': 2489279.56, 'tw_topic2_freq': 2335317.18, 'tw_comp_sum_last10_std': 2209588.52, 'tw_N_pos_last5_std': 2199700.67, 'tw_comp_mean': 2178262.48, 'tw_Reply_Count_sum': 2168741.81, 'tw_pos_std': 2032454.25, 'tw_Like_Count_sum_last5_std': 1928771.57, 'tw_Quote_Count_std': 1842626.82, 'tw_Reply_Count_std': 1825125.77, 'tw_Retweet_Count_std': 1726274.29, 'tw_Retweet_Count_sum_last5_std': 1655477.48, 'tw_Reply_Count_mean': 1639068.71, 'tw_topic1_freq': 1623360.57, 'tw_RelDiffPosNeg_sum_last5_std': 1621618.24, 'tw_Quote_Count_sum': 1508791.37, 'tw_pos_mean': 1445129.09, 'tw_neg_std': 1100833.01, 'tw_neg_mean': 869090.21, 'tw_neg_sum': 722227.17, 'MrBeast': 463089.75}
# ==============
# Importance type: cover
# {'tw_N_pos_last5_mean': 101.01, 'tw_N_last5_mean': 100.79, 'tw_Like_Count_sum_last10_mean': 87.65, 'tw_Retweet_Count_sum_last10_mean': 87.36, 'tw_RelDiffPosNeg_sum_last10_mean': 87.25, 'tw_N_pos': 86.5, 'tw_N_neg_last10_mean': 85.9, 'tw_N_last10_mean': 83.99, 'tw_N_pos_last10_mean': 82.21, 'tw_Retweet_Count_sum': 78.31, 'tw_Like_Count_sum': 74.5, 'tw_pos_sum_last10_mean': 73.54, 'tw_RelDiffPosNeg_sum_last5_mean': 73.08, 'tw_N_neg': 70.95, 'tw_comp_sum_last10_mean': 69.6, 'tw_comp_q5_count': 66.09, 'tw_comp_q1_count': 63.33, 'tw_neg_sum_last10_mean': 63.22, 'tw_RelDiffPosNeg_sum': 61.57, 'tw_Quote_Count_sum_last5_mean': 61.08, 'tw_N': 59.61, 'tw_N_neg_last5_mean': 59.41, 'tw_comp_sum_last5_mean': 59.33, 'tw_comp_q4_count': 59.31, 'tw_comp_sum_last10_std': 59.25, 'tw_comp_q2_count': 58.51, 'tw_pos_sum_last5_mean': 57.9, 'tw_Like_Count_sum_last5_mean': 57.54, 'tw_Reply_Count_sum_last10_std': 57.09, 'tw_Quote_Count_sum_last5_std': 54.84, 'tw_Retweet_Count_sum_last5_mean': 54.54, 'tw_comp_q3_count': 53.68, 'tw_Retweet_Count_sum_last5_std': 51.82, 'tw_Reply_Count_sum_last5_mean': 51.69, 'tw_Quote_Count_sum_last10_std': 51.2, 'tw_Reply_Count_sum_last10_mean': 50.58, 'tw_Like_Count_sum_last10_std': 50.46, 'tw_Retweet_Count_sum_last10_std': 49.74, 'elonmusk': 49.54, 'tw_Like_Count_sum_last5_std': 49.03, 'tw_Quote_Count_sum_last10_mean': 48.9, 'tw_Reply_Count_sum_last5_std': 48.68, 'tw_Quote_Count_sum': 48.23, 'tw_Retweet_Count_std': 47.73, 'tw_Quote_Count_std': 46.79, 'tw_comp_sum': 45.85, 'tw_RelDiffPosNeg_sum_last10_std': 45.3, 'tw_N_pos_last10_std': 44.85, 'tw_pos_sum_last10_std': 43.96, 'tw_N_neg_last10_std': 42.61, 'tw_Like_Count_std': 39.67, 'tw_Like_Count_mean': 39.67, 'tw_N_neg_last5_std': 39.26, 'tw_N_last10_std': 38.92, 'tw_Reply_Count_mean': 37.68, 'tw_Quote_Count_mean': 36.97, 'tw_neg_sum_last5_std': 34.93, 'tw_RelDiffPosNeg_sum_last5_std': 34.89, 'tw_N_pos_last5_std': 34.82, 'tw_neg_sum_last10_std': 34.66, 'tw_topic2_freq': 33.81, 'tw_neg_sum_last5_mean': 32.89, 'tw_comp_mean': 32.39, 'tw_topic3_freq': 31.2, 'tw_N_last5_std': 30.87, 'tw_topic1_freq': 30.83, 'tw_pos_sum_last5_std': 30.41, 'tw_Retweet_Count_mean': 30.0, 'tw_RelDiffPosNeg_mean': 29.99, 'tw_pos_sum': 29.82, 'tw_comp_sum_last5_std': 29.26, 'tw_Reply_Count_std': 28.09, 'tw_RelDiffPosNeg_std': 27.47, 'tw_Reply_Count_sum': 26.51, 'tw_comp_std': 25.87, 'tw_pos_std': 19.73, 'tw_pos_mean': 19.5, 'tw_neg_std': 18.22, 'MrBeast': 17.0, 'tw_neg_mean': 11.05, 'tw_neg_sum': 9.21}

# %% [markdown]
# ## Target: Absolute difference to the next day's BTC Close price

# %% [markdown]
# ### Prepare training and testing datasets

# %%
# Define target and input variables
target = 'Close_diff_next1'
variables = df_ana.columns.to_list()

# Split
y = df_ana[target]
X = df_ana[variables]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Remove all variables derived from the BTC Close price
skip_pattern = 'Close'

X_train_tmp = X_train[X_train.columns.drop(list(X_train.filter(like=skip_pattern)))].copy(deep=True)
X_train_tmp.drop(columns=['Date'], inplace=True)

X_test_tmp = X_test[X_test.columns.drop(list(X_test.filter(like=skip_pattern)))].copy(deep=True)
X_test_tmp.drop(columns=['Date'], inplace=True)

# %% [markdown]
# ### Prepare and train the model

# %%
model = xgb.XGBRegressor(n_estimators = 1000,\
                        learning_rate = 0.01,\
                        max_depth = 5,\
                        min_split_loss = 10,\
                        min_child_weight = 1,\
                        colsample_bytree = 0.7,\
                        subsample = 0.5,\
                        reg_lambda = 2,\
                        reg_alpha = 0)

#model.fit(X_train_tmp.drop(columns=['Date']),y_train)
model.fit(X_train_tmp,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=10, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=5,
#              min_child_weight=1, min_split_loss=10, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=4,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=2,
#              scale_pos_weight=1, subsample=0.5, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %% [markdown]
# ### Compute extra features for performance evaluation

# %%
y_pred=model.predict(X_test_tmp)

X_test['Pred_diff_next1'] = list(y_pred)
X_test['Pred_diff_next1_rel'] = (X_test.Pred_diff_next1/X_test.Close).to_list()
X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1)
# Out:
# <ipython-input-16-b6d71e7a9ad9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1'] = list(y_pred)
# <ipython-input-16-b6d71e7a9ad9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_rel'] = (X_test.Pred_diff_next1/X_test.Close).to_list()
# <ipython-input-16-b6d71e7a9ad9>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1)

# %% [markdown]
# ### Performance evaluation

# %%
print('==================================================================================')
print('Performance on the absolute diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1']
pred = X_test['Pred_diff_next1']
print('+++ Diff to next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the relative diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_rel']
pred = X_test['Pred_diff_next1_rel']
print('+++ Relative diff to next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the signed diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_sgn']
pred = X_test['Pred_diff_next1_sgn']
print('+++ Next day BTC price')
print(f"Accuracy:    {accuracy_score(test, pred)}")
# Out:
# ==================================================================================
# Performance on the absolute diff between today's and next day's BTC Close price
# +++ Diff to next day BTC price
# Explained variance:    -0.1485947138476691
# R2:                    -0.16994901877180046
# MAE:                   541.365710856809
# MSE:                   935445.9425497628
#
# ==================================================================================
# Performance on the relative diff between today's and next day's BTC Close price
# +++ Relative diff to next day BTC price
# Explained variance:    -0.20160352932034198
# R2:                    -963.6949629408953
# MAE:                   0.9964776156963714
# MSE:                   0.9942060004339248
#
# ==================================================================================
# Performance on the signed diff between today's and next day's BTC Close price
# +++ Next day BTC price
# Accuracy:    0.5373134328358209

# %%
import operator

for importance_type in ['weight', 'gain', 'cover']:

    # Get the importance dictionary (by gain) from the booster
    importance = model.get_booster().get_score(importance_type=importance_type)

    # make your changes
    for key in importance.keys():
        importance[key] = round(importance[key],2)
        
    print('==============')
    print(f'Importance type: {importance_type}')
    print(dict(sorted(importance.items(),
                            key=operator.itemgetter(1),
                            reverse=True)))

    # provide the importance dictionary to the plotting function
    #ax = plot_importance(importance, max_num_features=3, importance_type='gain', show_values=True)

    # Plot variable importance
    ax = xgb.plot_importance(importance, max_num_features=10, grid=False, xlabel=None,\
                             title='Feature importance according to '+importance_type)
    fig = ax.figure
    fig.set_size_inches(10, 10)
# Out:
# ==============
# Importance type: weight
# {'tw_neg_sum': 1477, 'tw_neg_mean': 927, 'tw_neg_std': 533, 'tw_pos_mean': 444, 'tw_pos_std': 416, 'tw_pos_sum': 383, 'tw_comp_std': 352, 'tw_RelDiffPosNeg_std': 321, 'tw_neg_sum_last10_mean': 293, 'tw_comp_sum': 276, 'tw_Retweet_Count_sum_last5_std': 272, 'tw_topic1_freq': 262, 'tw_Reply_Count_mean': 244, 'tw_Retweet_Count_sum_last10_std': 240, 'tw_Quote_Count_sum_last10_std': 233, 'tw_Retweet_Count_mean': 225, 'tw_Like_Count_mean': 223, 'tw_Reply_Count_sum': 222, 'tw_comp_mean': 202, 'tw_Reply_Count_sum_last5_mean': 199, 'tw_RelDiffPosNeg_mean': 197, 'tw_Like_Count_std': 192, 'tw_topic2_freq': 190, 'tw_neg_sum_last5_std': 189, 'tw_Quote_Count_sum_last5_std': 178, 'tw_Like_Count_sum_last10_std': 175, 'tw_Quote_Count_mean': 173, 'tw_topic3_freq': 167, 'tw_neg_sum_last10_std': 167, 'tw_Quote_Count_std': 165, 'tw_RelDiffPosNeg_sum': 161, 'tw_pos_sum_last5_std': 161, 'tw_Retweet_Count_std': 160, 'tw_Reply_Count_std': 159, 'tw_RelDiffPosNeg_sum_last5_std': 153, 'tw_neg_sum_last5_mean': 153, 'tw_Like_Count_sum': 142, 'tw_Reply_Count_sum_last5_std': 138, 'tw_comp_sum_last10_std': 134, 'tw_N_neg_last10_std': 134, 'tw_comp_sum_last5_std': 127, 'tw_N_neg': 127, 'tw_comp_q4_count': 127, 'tw_Retweet_Count_sum': 125, 'tw_Reply_Count_sum_last10_std': 123, 'tw_pos_sum_last10_mean': 122, 'tw_Retweet_Count_sum_last5_mean': 120, 'tw_RelDiffPosNeg_sum_last10_std': 120, 'tw_Quote_Count_sum': 118, 'tw_Reply_Count_sum_last10_mean': 115, 'tw_comp_q3_count': 115, 'tw_comp_sum_last10_mean': 115, 'tw_Like_Count_sum_last5_std': 114, 'tw_comp_q5_count': 112, 'tw_Quote_Count_sum_last10_mean': 106, 'tw_comp_sum_last5_mean': 103, 'tw_Like_Count_sum_last10_mean': 102, 'tw_Like_Count_sum_last5_mean': 97, 'tw_pos_sum_last10_std': 97, 'tw_N_last5_std': 96, 'tw_Retweet_Count_sum_last10_mean': 95, 'tw_N_neg_last5_std': 92, 'tw_pos_sum_last5_mean': 91, 'tw_comp_q2_count': 86, 'tw_N_last10_std': 86, 'tw_Quote_Count_sum_last5_mean': 83, 'tw_N_neg_last5_mean': 83, 'tw_comp_q1_count': 79, 'tw_N_neg_last10_mean': 79, 'tw_N_pos_last5_std': 79, 'tw_N_last10_mean': 75, 'tw_RelDiffPosNeg_sum_last10_mean': 71, 'tw_RelDiffPosNeg_sum_last5_mean': 62, 'tw_N_pos_last10_std': 54, 'tw_N_last5_mean': 52, 'tw_N': 51, 'tw_N_pos_last5_mean': 32, 'tw_N_pos_last10_mean': 27, 'tw_N_pos': 26, 'elonmusk': 2}
# ==============
# Importance type: gain
# {'tw_comp_q4_count': 4490038.61, 'tw_Reply_Count_sum_last10_mean': 3931118.97, 'elonmusk': 3706302.88, 'tw_N_last5_mean': 3416969.47, 'tw_Like_Count_sum_last10_std': 2914477.17, 'tw_N_neg_last10_mean': 2868021.82, 'tw_Retweet_Count_sum_last5_mean': 2793108.59, 'tw_neg_sum_last10_mean': 2683294.01, 'tw_N_last10_mean': 2673689.83, 'tw_N_neg': 2629949.83, 'tw_comp_sum_last10_mean': 2600979.08, 'tw_N': 2533320.88, 'tw_RelDiffPosNeg_sum_last10_std': 2464647.45, 'tw_Retweet_Count_sum_last10_std': 2435336.74, 'tw_pos_sum_last10_mean': 2404065.41, 'tw_N_neg_last5_mean': 2391718.0, 'tw_Like_Count_sum_last10_mean': 2363128.97, 'tw_Reply_Count_sum_last10_std': 2314485.48, 'tw_Retweet_Count_sum_last10_mean': 2298695.75, 'tw_N_pos_last5_mean': 2273296.16, 'tw_pos_sum_last5_mean': 2235105.53, 'tw_Like_Count_sum_last5_mean': 2224822.52, 'tw_RelDiffPosNeg_sum_last10_mean': 2197836.59, 'tw_comp_sum_last10_std': 2194783.0, 'tw_neg_sum_last5_mean': 2108224.84, 'tw_RelDiffPosNeg_sum_last5_mean': 2036755.54, 'tw_RelDiffPosNeg_sum': 1798191.83, 'tw_comp_q2_count': 1788946.57, 'tw_Reply_Count_sum_last5_mean': 1780579.97, 'tw_Quote_Count_sum_last10_mean': 1751144.17, 'tw_N_last10_std': 1707966.56, 'tw_N_pos': 1604436.86, 'tw_N_pos_last10_mean': 1533244.1, 'tw_comp_q5_count': 1487563.39, 'tw_comp_q1_count': 1400801.51, 'tw_Quote_Count_sum_last10_std': 1391126.74, 'tw_Quote_Count_sum_last5_std': 1377471.37, 'tw_comp_sum_last5_mean': 1357607.19, 'tw_comp_q3_count': 1337384.01, 'tw_Reply_Count_sum': 1322548.42, 'tw_neg_sum_last5_std': 1315012.38, 'tw_Like_Count_sum_last5_std': 1283364.33, 'tw_Retweet_Count_sum_last5_std': 1216140.5, 'tw_N_neg_last10_std': 1202643.94, 'tw_neg_sum_last10_std': 1187243.66, 'tw_Retweet_Count_sum': 1176583.75, 'tw_Like_Count_sum': 1153563.02, 'tw_N_pos_last10_std': 1110717.28, 'tw_comp_mean': 1091164.0, 'tw_N_neg_last5_std': 1081261.15, 'tw_pos_std': 1043621.43, 'tw_Quote_Count_sum_last5_mean': 1036333.15, 'tw_Reply_Count_sum_last5_std': 1005261.97, 'tw_Quote_Count_mean': 999610.75, 'tw_Quote_Count_sum': 992059.55, 'tw_comp_sum_last5_std': 977866.25, 'tw_pos_sum_last5_std': 941089.84, 'tw_Like_Count_mean': 932424.63, 'tw_Quote_Count_std': 909784.15, 'tw_pos_mean': 878866.81, 'tw_Reply_Count_mean': 872551.13, 'tw_RelDiffPosNeg_std': 854860.67, 'tw_comp_sum': 850216.2, 'tw_comp_std': 778381.82, 'tw_Like_Count_std': 759513.3, 'tw_topic2_freq': 728694.29, 'tw_RelDiffPosNeg_sum_last5_std': 725064.69, 'tw_Retweet_Count_std': 692142.11, 'tw_topic1_freq': 662988.73, 'tw_topic3_freq': 658459.16, 'tw_N_pos_last5_std': 649981.37, 'tw_pos_sum_last10_std': 624699.01, 'tw_RelDiffPosNeg_mean': 613991.67, 'tw_Retweet_Count_mean': 606182.96, 'tw_N_last5_std': 571876.5, 'tw_Reply_Count_std': 555171.19, 'tw_pos_sum': 554690.98, 'tw_neg_std': 448667.99, 'tw_neg_mean': 421474.66, 'tw_neg_sum': 366930.09}
# ==============
# Importance type: cover
# {'tw_Retweet_Count_sum_last10_std': 108.87, 'tw_N_neg_last5_mean': 101.75, 'tw_N_pos_last10_mean': 96.04, 'tw_Retweet_Count_sum_last10_mean': 95.53, 'tw_Like_Count_sum_last10_mean': 94.36, 'tw_N_pos_last5_mean': 94.06, 'tw_Retweet_Count_sum_last5_std': 92.57, 'tw_Like_Count_sum_last10_std': 91.26, 'tw_neg_sum_last10_mean': 90.0, 'tw_N_neg_last10_mean': 89.89, 'tw_N_last5_mean': 89.29, 'tw_N_neg_last10_std': 86.0, 'tw_Retweet_Count_sum_last5_mean': 84.88, 'tw_N_last10_mean': 84.63, 'tw_Quote_Count_sum_last10_std': 84.59, 'tw_Like_Count_sum_last5_mean': 81.7, 'tw_comp_q4_count': 80.65, 'tw_RelDiffPosNeg_sum_last10_std': 80.28, 'tw_comp_sum_last10_std': 78.69, 'tw_RelDiffPosNeg_sum_last5_mean': 78.21, 'tw_comp_sum_last10_mean': 74.84, 'tw_Quote_Count_sum_last5_std': 72.86, 'tw_pos_sum_last5_mean': 71.97, 'tw_RelDiffPosNeg_sum_last10_mean': 69.58, 'tw_neg_sum_last10_std': 68.71, 'tw_N_last10_std': 67.77, 'tw_pos_sum_last10_mean': 67.21, 'tw_comp_q1_count': 67.19, 'tw_Reply_Count_sum_last10_std': 64.28, 'tw_RelDiffPosNeg_sum_last5_std': 63.95, 'tw_Quote_Count_sum_last10_mean': 63.06, 'tw_N_neg': 62.19, 'tw_N': 62.08, 'tw_Reply_Count_sum_last5_std': 60.43, 'tw_comp_q3_count': 59.95, 'tw_comp_q5_count': 59.5, 'tw_Retweet_Count_mean': 59.05, 'tw_Reply_Count_sum_last5_mean': 58.91, 'tw_comp_sum_last5_mean': 58.87, 'tw_neg_sum_last5_mean': 57.95, 'tw_Quote_Count_sum_last5_mean': 57.34, 'tw_Reply_Count_sum_last10_mean': 56.82, 'tw_N_pos_last10_std': 55.96, 'tw_N_pos_last5_std': 52.76, 'tw_RelDiffPosNeg_sum': 52.51, 'tw_pos_sum_last10_std': 49.96, 'tw_N_neg_last5_std': 49.67, 'tw_comp_q2_count': 48.38, 'tw_N_pos': 47.42, 'tw_topic1_freq': 47.13, 'tw_N_last5_std': 45.55, 'tw_neg_sum_last5_std': 45.38, 'tw_Like_Count_mean': 45.0, 'tw_Quote_Count_std': 43.21, 'tw_Like_Count_sum': 42.18, 'tw_Like_Count_sum_last5_std': 42.14, 'tw_Reply_Count_mean': 38.97, 'tw_Retweet_Count_sum': 37.82, 'tw_RelDiffPosNeg_mean': 37.56, 'tw_Reply_Count_sum': 37.18, 'tw_topic3_freq': 36.84, 'tw_Like_Count_std': 36.78, 'tw_Reply_Count_std': 35.43, 'tw_topic2_freq': 34.66, 'tw_pos_sum_last5_std': 33.38, 'tw_Retweet_Count_std': 33.11, 'tw_RelDiffPosNeg_std': 30.88, 'tw_Quote_Count_mean': 29.04, 'tw_comp_mean': 28.54, 'tw_comp_sum_last5_std': 26.38, 'tw_Quote_Count_sum': 23.97, 'tw_comp_sum': 21.98, 'tw_pos_mean': 21.82, 'tw_comp_std': 21.16, 'tw_pos_std': 20.78, 'tw_neg_std': 18.08, 'elonmusk': 15.0, 'tw_pos_sum': 12.15, 'tw_neg_mean': 10.86, 'tw_neg_sum': 9.22}

# %% [markdown]
# ## Target: Relative difference to the next day's BTC Close price

# %% [markdown]
# ### Prepare training and testing datasets

# %%
# Define target and input variables
target = 'Close_diff_next1_rel'
variables = df_ana.columns.to_list()

# Split
y = df_ana[target]
X = df_ana[variables]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Remove all variables derived from the BTC Close price
skip_pattern = 'Close'

X_train_tmp = X_train[X_train.columns.drop(list(X_train.filter(like=skip_pattern)))].copy(deep=True)
X_train_tmp.drop(columns=['Date'], inplace=True)

X_test_tmp = X_test[X_test.columns.drop(list(X_test.filter(like=skip_pattern)))].copy(deep=True)
X_test_tmp.drop(columns=['Date'], inplace=True)

# %% [markdown]
# ### Prepare and train the model

# %%
model = xgb.XGBRegressor(n_estimators = 1000,\
                        learning_rate = 0.01,\
                        max_depth = 5,\
                        min_split_loss = 10,\
                        min_child_weight = 1,\
                        colsample_bytree = 0.7,\
                        subsample = 0.5,\
                        reg_lambda = 2,\
                        reg_alpha = 0)

#model.fit(X_train_tmp.drop(columns=['Date']),y_train)
model.fit(X_train_tmp,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=10, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=5,
#              min_child_weight=1, min_split_loss=10, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=4,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=2,
#              scale_pos_weight=1, subsample=0.5, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %% [markdown]
# ### Compute extra features for performance evaluation

# %%
y_pred=model.predict(X_test_tmp)

X_test['Pred_diff_next1'] = list(y_pred)
X_test['Pred_diff_next1_rel'] = list(y_pred)
X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1_rel)
# Out:
# <ipython-input-21-86142636e4f0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1'] = list(y_pred)
# <ipython-input-21-86142636e4f0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_rel'] = list(y_pred)
# <ipython-input-21-86142636e4f0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1_rel)

# %% [markdown]
# ### Performance evaluation

# %%
print('==================================================================================')
print('Performance on the relative diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_rel']
pred = X_test['Pred_diff_next1_rel']
print('+++ Relative diff to next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the signed diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_sgn']
pred = X_test['Pred_diff_next1_sgn']
print('+++ Next day BTC price')
print(f"Accuracy:    {accuracy_score(test, pred)}")
# Out:
# ==================================================================================
# Performance on the relative diff between today's and next day's BTC Close price
# +++ Relative diff to next day BTC price
# Explained variance:    2.220446049250313e-16
# R2:                    -0.01599615010776767
# MAE:                   0.021703514819490833
# MSE:                   0.001047076545082776
#
# ==================================================================================
# Performance on the signed diff between today's and next day's BTC Close price
# +++ Next day BTC price
# Accuracy:    0.5671641791044776

# %% [markdown]
# ## Target: Signed difference to the next day's BTC Close price

# %% [markdown]
# ### Prepare training and testing datasets

# %%
# Define target and input variables
target = 'Close_diff_next1_sgn'
variables = df_ana.columns.to_list()

# Split
y = df_ana[target]
X = df_ana[variables]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
#X_test.sort_values(by=['Date'], inplace=True)

# Remove all variables derived from the BTC Close price
skip_pattern = 'Close'

X_train_tmp = X_train[X_train.columns.drop(list(X_train.filter(like=skip_pattern)))].copy(deep=True)
X_train_tmp.drop(columns=['Date'], inplace=True)

X_test_tmp = X_test[X_test.columns.drop(list(X_test.filter(like=skip_pattern)))].copy(deep=True)
X_test_tmp.drop(columns=['Date'], inplace=True)

# %% [markdown]
# ### Prepare and train the model

# %%
imbalance = len(y_train)/sum(y_train)

xgb_model = xgb.XGBClassifier(objective="binary:logistic", n_estimators=20,\
                              random_state=42, eval_metric=["auc"],\
                             #scale_pos_weight=imbalance
                             )
#eval_metric=["auc", "error", "error@0.6"]

#xgb_model.fit(X_train, y_train, eval_set=[(X_test, y_test)])
xgb_model.fit(X_train_tmp, y_train)

y_pred = xgb_model.predict(X_test_tmp)
# Out:
# /Users/snezana/testenv/lib/python3.9/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %% [markdown]
# ### Performance evaluation

# %%
from sklearn.metrics import classification_report,confusion_matrix

print('==================================================================================')
print('Performance on the signed diff between today\'s and next day\'s BTC Close price' )
print()
print('Accuracy:')
print(accuracy_score(y_test,y_pred))
print()
print('Confusion matrix:')
print(confusion_matrix(y_test,y_pred))
print()
print('Classification report:')
print(classification_report(y_test,y_pred))
# Out:
# ==================================================================================
# Performance on the signed diff between today's and next day's BTC Close price
#
# Accuracy:
# 0.582089552238806
#
# Confusion matrix:
# [[13 16]
#  [12 26]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#         -1.0       0.52      0.45      0.48        29
#          1.0       0.62      0.68      0.65        38
#
#     accuracy                           0.58        67
#    macro avg       0.57      0.57      0.57        67
# weighted avg       0.58      0.58      0.58        67
