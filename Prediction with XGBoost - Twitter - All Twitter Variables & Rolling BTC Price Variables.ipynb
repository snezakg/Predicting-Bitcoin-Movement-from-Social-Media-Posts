# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sb
import matplotlib.colors as mcolors

import time
from datetime import datetime, timedelta

from sklearn.model_selection import train_test_split
import xgboost as xgb

# Metrics
from sklearn.metrics import explained_variance_score
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn import metrics

# Cross-validation
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_validate

#from sklearn import preprocessing
#from sklearn.pipeline import make_pipeline
from xgboost import XGBRegressor
from xgboost import XGBRFRegressor
#from sklearn.model_selection import GridSearchCV
#from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# # Import prepared dataframes

# %%
# Bitcoin
df_btc = pd.read_csv('df_btc.csv')
df_btc.Date = pd.to_datetime(df_btc.Date)

# Twitter
df_tw = pd.read_csv('df_tw_agg.csv')
df_tw.Date = pd.to_datetime(df_tw.Date)

# %% [markdown]
# # Construct the analysis dataframe

# %% [markdown]
# ### Select the Twitter variables to be used

# %%
variables = list(df_tw.columns)

# %% [markdown]
# ### Merge Bitcoin and Twitter dataframes

# %%
# Apply selection on the BTC dataframe
df_ana = df_btc[(df_btc.Date >= pd.to_datetime('01-04-2020', format='%d-%m-%Y')) & \
       (df_btc.Date < pd.to_datetime('15-03-2021', format='%d-%m-%Y'))]
#df_ana = df_ana[['Date', 'Close', 'Close_next1', 'Close_diff_next1', 'Close_diff_next1_rel', 'Close_diff_next1_sgn']]
df_ana = df_ana.dropna()

# Merge with TW dataframe
df_ana = pd.merge(left=df_ana, right=df_tw[variables], how='inner', left_on='Date', right_on='Date')
df_ana.dropna(inplace=True)

# %% [markdown]
# ### Study correlations among features

# %%
corr = df_ana.corr()
plt.figure(figsize = (20,20))
sb.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Target: next day's Bitcoin Close price

# %% [markdown]
# ### Prepare training and testing datasets

# %%
# Define target and input variables
target = 'Close_next1'
variables = df_ana.columns.to_list()

# Split
y = df_ana[target]
X = df_ana[variables]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
#X_test.sort_values(by=['Date'], inplace=True)

# Remove all variables derived from the BTC Close price
skip_pattern = 'next'

X_train_tmp = X_train[X_train.columns.drop(list(X_train.filter(like=skip_pattern)))].copy(deep=True)
X_train_tmp.drop(columns=['Date'], inplace=True)

X_test_tmp = X_test[X_test.columns.drop(list(X_test.filter(like=skip_pattern)))].copy(deep=True)
X_test_tmp.drop(columns=['Date'], inplace=True)

# %% [markdown]
# ### Prepare and train the model

# %%
model = xgb.XGBRegressor(n_estimators = 1000,\
                        learning_rate = 0.01,\
                        max_depth = 5,\
                        min_split_loss = 10,\
                        min_child_weight = 1,\
                        colsample_bytree = 0.7,\
                        subsample = 0.5,\
                        reg_lambda = 2,\
                        reg_alpha = 0)

#model.fit(X_train_tmp.drop(columns=['Date']),y_train)
model.fit(X_train_tmp,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=10, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=5,
#              min_child_weight=1, min_split_loss=10, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=4,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=2,
#              scale_pos_weight=1, subsample=0.5, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %% [markdown]
# ### Compute extra features for performance evaluation

# %%
y_pred=model.predict(X_test_tmp)
X_test['Pred_next1'] = list(y_pred)
X_test['Pred_diff_next1'] = (X_test.Pred_next1 - X_test.Close).to_list()
X_test['Pred_diff_next1_rel'] = (X_test.Pred_diff_next1/X_test.Close).to_list()
X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1)
# Out:
# <ipython-input-7-e9ddb46e0ea7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_next1'] = list(y_pred)
# <ipython-input-7-e9ddb46e0ea7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1'] = (X_test.Pred_next1 - X_test.Close).to_list()
# <ipython-input-7-e9ddb46e0ea7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_rel'] = (X_test.Pred_diff_next1/X_test.Close).to_list()
# <ipython-input-7-e9ddb46e0ea7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1)

# %% [markdown]
# ### Performance evaluation

# %%
print('==================================================================================')
print('Performance on the target variable: next day\'s BTC Close price' )
test = X_test['Close_next1']
pred = X_test['Pred_next1']
print('+++ Next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the absolute diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1']
pred = X_test['Pred_diff_next1']
print('+++ Diff to next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the relative diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_rel']
pred = X_test['Pred_diff_next1_rel']
print('+++ Relative diff to next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the signed diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_sgn']
pred = X_test['Pred_diff_next1_sgn']
print('+++ Next day BTC price')
print(f"Accuracy:    {accuracy_score(test, pred)}")
# Out:
# ==================================================================================
# Performance on the target variable: next day's BTC Close price
# +++ Next day BTC price
# Explained variance:    0.9928705122998045
# R2:                    0.9928507154214088
# MAE:                   537.1236080153917
# MSE:                   1032549.8687589376
#
# ==================================================================================
# Performance on the absolute diff between today's and next day's BTC Close price
# +++ Diff to next day BTC price
# Explained variance:    -0.2878195605888889
# R2:                    -0.2913955268165662
# MAE:                   537.1236080153917
# MSE:                   1032549.8687589376
#
# ==================================================================================
# Performance on the relative diff between today's and next day's BTC Close price
# +++ Relative diff to next day BTC price
# Explained variance:    -0.2718989003248993
# R2:                    -968.9063698418615
# MAE:                   0.9991326349108256
# MSE:                   0.9995768297744745
#
# ==================================================================================
# Performance on the signed diff between today's and next day's BTC Close price
# +++ Next day BTC price
# Accuracy:    0.5970149253731343

# %% [markdown]
# ### Plot predictions

# %%
# Next day's BTC price

X_test.sort_values(by=['Date'], inplace=True)
x = X_test.Date
y_test = X_test['Close_next1']
y_pred = X_test['Pred_next1']

fig, ax = plt.subplots(figsize=(15, 5))

ax.set_xlabel('Date')
ax.set_ylabel('Next day BTC price')
ax.plot(x, y_test, color='tab:red', label='Ground Truth')
ax.plot(x, y_pred, color='tab:blue', label='Prediction')

plt.legend()
#ax1.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
# Out:
# <ipython-input-9-c9312ce135ef>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.sort_values(by=['Date'], inplace=True)

# %%
# Absolute diff to next day's BTC price

x = X_test.Date
y_test = X_test['Close_diff_next1']
y_pred = X_test['Pred_diff_next1']

fig, ax = plt.subplots(figsize=(15, 5))

ax.set_xlabel('Date')
ax.set_ylabel('Absolute diff to next day\'s BTC price')
ax.plot(x, y_test, color='tab:red', label='Ground Truth')
ax.plot(x, y_pred, color='tab:blue', label='Prediction')

plt.legend()
#ax1.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
# Relative diff to next day's BTC price

x = X_test.Date
y_test = X_test['Close_diff_next1_rel']
y_pred = X_test['Pred_diff_next1_rel']

fig, ax = plt.subplots(figsize=(15, 5))

ax.set_xlabel('Date')
ax.set_ylabel('Relative diff to next day\'s BTC price')
ax.plot(x, y_test, color='tab:red', label='Ground Truth')
ax.plot(x, y_pred, color='tab:blue', label='Prediction')

plt.legend()
#ax1.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
# Signed diff to next day's BTC price

x = X_test.Date
y_test = X_test['Close_diff_next1_sgn']
y_pred = X_test['Pred_diff_next1_sgn']

fig, ax = plt.subplots(figsize=(15, 5))

ax.set_xlabel('Date')
ax.set_ylabel('Relative diff to next day\'s BTC price')
ax.plot(x, y_test, color='tab:red', label='Ground Truth')
ax.plot(x, y_pred, color='tab:blue', label='Prediction')

plt.legend()
#ax1.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %% [markdown]
# ### Feature importance

# %%
import operator

for importance_type in ['weight', 'gain', 'cover']:

    # Get the importance dictionary (by gain) from the booster
    importance = model.get_booster().get_score(importance_type=importance_type)

    # make your changes
    for key in importance.keys():
        importance[key] = round(importance[key],2)
        
    print('==============')
    print(f'Importance type: {importance_type}')
    print(dict(sorted(importance.items(),
                            key=operator.itemgetter(1),
                            reverse=True)))

    # provide the importance dictionary to the plotting function
    #ax = plot_importance(importance, max_num_features=3, importance_type='gain', show_values=True)

    # Plot variable importance
    ax = xgb.plot_importance(importance, max_num_features=10, grid=False, xlabel=None,\
                             title='Feature importance according to '+importance_type)
    fig = ax.figure
    fig.set_size_inches(10, 10)
# Out:
# ==============
# Importance type: weight
# {'Close': 1635, 'Close_last7_mean': 748, 'Close_last7_std': 391, 'Close_last5_mean': 343, 'Close_last2_mean': 255, 'Close_diff_last1': 238, 'Close_last3_mean': 234, 'Close_last2_std': 229, 'Close_last5_std': 225, 'Close_diff_last2': 204, 'Close_last3_std': 187, 'Close_diff_last5': 178, 'Close_diff_last3': 173, 'tw_pos_std': 147, 'Close_diff_last7': 139, 'tw_neg_sum': 136, 'tw_topic2_freq': 129, 'tw_pos_mean': 129, 'tw_Like_Count_mean': 128, 'tw_RelDiffPosNeg_std': 127, 'tw_neg_mean': 125, 'tw_Retweet_Count_mean': 125, 'tw_neg_std': 122, 'tw_Reply_Count_mean': 117, 'tw_neg_sum_last10_mean': 110, 'Close_diff_last7_rel': 109, 'tw_Reply_Count_sum_last5_mean': 106, 'tw_topic1_freq': 105, 'tw_topic3_freq': 100, 'Close_diff_last2_rel': 95, 'tw_comp_std': 91, 'tw_comp_mean': 90, 'Close_diff_last1_rel': 89, 'tw_RelDiffPosNeg_mean': 88, 'tw_comp_q4_count': 87, 'tw_RelDiffPosNeg_sum_last10_std': 86, 'tw_Quote_Count_sum_last10_std': 84, 'tw_Like_Count_std': 82, 'tw_comp_sum_last5_std': 82, 'tw_comp_sum_last10_std': 78, 'tw_Reply_Count_std': 77, 'tw_Retweet_Count_std': 76, 'tw_Quote_Count_std': 76, 'tw_neg_sum_last5_mean': 74, 'Close_diff_last3_rel': 73, 'tw_comp_sum': 72, 'tw_RelDiffPosNeg_sum_last5_std': 72, 'tw_Like_Count_sum': 71, 'tw_Reply_Count_sum': 71, 'tw_Like_Count_sum_last10_mean': 70, 'tw_RelDiffPosNeg_sum_last10_mean': 70, 'tw_Reply_Count_sum_last5_std': 70, 'tw_pos_sum_last10_mean': 67, 'tw_Retweet_Count_sum_last10_mean': 67, 'tw_neg_sum_last10_std': 67, 'tw_comp_sum_last10_mean': 65, 'Close_diff_last5_rel': 65, 'tw_RelDiffPosNeg_sum': 64, 'tw_Reply_Count_sum_last10_mean': 64, 'tw_Quote_Count_mean': 63, 'tw_pos_sum_last10_std': 59, 'tw_Retweet_Count_sum_last5_mean': 59, 'tw_Retweet_Count_sum': 59, 'tw_Retweet_Count_sum_last5_std': 58, 'tw_Quote_Count_sum_last5_std': 58, 'tw_pos_sum': 57, 'tw_N_neg': 57, 'tw_Retweet_Count_sum_last10_std': 53, 'tw_Quote_Count_sum_last10_mean': 52, 'tw_comp_sum_last5_mean': 51, 'tw_neg_sum_last5_std': 51, 'tw_Like_Count_sum_last10_std': 50, 'tw_Reply_Count_sum_last10_std': 50, 'tw_comp_q2_count': 50, 'tw_Quote_Count_sum_last5_mean': 48, 'tw_pos_sum_last5_std': 48, 'tw_pos_sum_last5_mean': 45, 'tw_comp_q3_count': 44, 'tw_comp_q5_count': 44, 'tw_RelDiffPosNeg_sum_last5_mean': 42, 'tw_Quote_Count_sum': 42, 'tw_comp_q1_count': 40, 'tw_N_neg_last10_std': 36, 'tw_Like_Count_sum_last5_std': 32, 'tw_Like_Count_sum_last5_mean': 32, 'tw_N_last10_mean': 31, 'tw_N_neg_last5_std': 31, 'tw_N_pos_last5_std': 30, 'tw_N_pos_last5_mean': 29, 'tw_N_last5_std': 29, 'tw_N_pos_last10_std': 26, 'tw_N_neg_last10_mean': 24, 'tw_N_last10_std': 24, 'tw_N_last5_mean': 23, 'tw_N_neg_last5_mean': 23, 'tw_N': 22, 'tw_N_pos_last10_mean': 16, 'tw_N_pos': 12, 'elonmusk': 2}
# ==============
# Importance type: gain
# {'tw_N_pos_last10_mean': 933920946.27, 'tw_N_last5_mean': 754829231.29, 'tw_N_pos_last5_mean': 544779113.71, 'tw_pos_sum_last10_mean': 401397960.67, 'Close': 399914929.47, 'tw_Retweet_Count_sum_last10_mean': 374377853.97, 'Close_last3_mean': 318942492.34, 'Close_last7_mean': 276498502.13, 'Close_last5_mean': 270834570.73, 'tw_comp_sum_last10_mean': 251318328.09, 'tw_neg_sum_last10_mean': 250807198.96, 'tw_RelDiffPosNeg_sum_last5_mean': 205636266.18, 'tw_Like_Count_sum_last10_mean': 193251993.54, 'tw_RelDiffPosNeg_sum_last10_mean': 180806802.1, 'tw_pos_sum_last5_mean': 123751210.29, 'Close_last2_mean': 102506659.97, 'tw_Like_Count_sum': 78086766.48, 'tw_N_last10_mean': 51018180.51, 'tw_RelDiffPosNeg_sum': 15492080.71, 'tw_comp_q4_count': 6075160.46, 'tw_Reply_Count_sum_last5_mean': 5920767.01, 'tw_comp_sum_last5_mean': 5678771.31, 'tw_Like_Count_sum_last5_mean': 5089267.32, 'tw_neg_sum_last10_std': 4592884.15, 'tw_N_neg_last10_std': 3996615.14, 'tw_comp_q3_count': 3576537.53, 'Close_last7_std': 3325601.45, 'tw_comp_sum_last5_std': 2883834.45, 'Close_diff_last3': 2780958.6, 'tw_Reply_Count_sum_last10_mean': 2675012.7, 'Close_diff_last7': 2625932.11, 'Close_diff_last2': 2230629.52, 'Close_diff_last5': 2199527.09, 'tw_N_neg_last10_mean': 2040659.96, 'tw_Retweet_Count_sum_last5_mean': 1940810.6, 'tw_topic2_freq': 1936490.41, 'tw_comp_sum_last10_std': 1868525.28, 'Close_diff_last3_rel': 1646727.02, 'tw_RelDiffPosNeg_sum_last10_std': 1446983.7, 'tw_Quote_Count_sum_last10_mean': 1397001.07, 'tw_Reply_Count_std': 1390352.26, 'tw_Retweet_Count_sum': 1362369.46, 'tw_pos_std': 1345235.42, 'tw_N_neg_last5_std': 1339184.82, 'tw_Like_Count_mean': 1282586.24, 'tw_pos_sum_last10_std': 1277404.14, 'Close_diff_last1': 1216999.56, 'tw_Retweet_Count_sum_last10_std': 1209389.59, 'tw_topic1_freq': 1192553.65, 'tw_Like_Count_std': 1179444.76, 'Close_last5_std': 1177958.85, 'tw_RelDiffPosNeg_mean': 1149110.81, 'tw_N_neg_last5_mean': 1133393.44, 'tw_neg_sum_last5_mean': 1132768.09, 'tw_N_neg': 1105281.64, 'tw_Reply_Count_sum_last5_std': 1081850.15, 'tw_N_pos_last10_std': 1080341.08, 'tw_RelDiffPosNeg_std': 1064167.72, 'tw_Reply_Count_sum_last10_std': 1044337.03, 'tw_comp_q2_count': 987639.71, 'tw_Like_Count_sum_last10_std': 968405.33, 'elonmusk': 924113.75, 'tw_comp_sum': 915311.76, 'Close_last2_std': 875553.62, 'tw_neg_sum_last5_std': 868779.21, 'tw_Reply_Count_sum': 863421.83, 'tw_N_last10_std': 853122.83, 'tw_N_pos': 851966.34, 'Close_diff_last2_rel': 845527.99, 'tw_neg_std': 816827.53, 'tw_Quote_Count_mean': 805859.87, 'tw_neg_mean': 793371.62, 'tw_RelDiffPosNeg_sum_last5_std': 779461.85, 'tw_pos_sum_last5_std': 766836.56, 'Close_diff_last7_rel': 758580.28, 'tw_comp_q5_count': 756693.93, 'tw_N_pos_last5_std': 701597.27, 'tw_neg_sum': 684045.35, 'Close_diff_last1_rel': 666016.55, 'tw_Quote_Count_sum_last5_mean': 645300.35, 'Close_diff_last5_rel': 636587.06, 'tw_Like_Count_sum_last5_std': 622431.46, 'tw_N': 616277.31, 'tw_Quote_Count_sum_last10_std': 612680.26, 'tw_Reply_Count_mean': 577624.63, 'tw_Quote_Count_sum': 573693.82, 'Close_last3_std': 560320.54, 'tw_pos_sum': 546989.63, 'tw_comp_mean': 545588.26, 'tw_pos_mean': 526598.15, 'tw_topic3_freq': 496862.36, 'tw_Retweet_Count_sum_last5_std': 484115.02, 'tw_Retweet_Count_std': 466926.77, 'tw_N_last5_std': 459842.86, 'tw_Quote_Count_std': 424813.93, 'tw_Retweet_Count_mean': 310623.24, 'tw_comp_q1_count': 309973.95, 'tw_Quote_Count_sum_last5_std': 307968.4, 'tw_comp_std': 296863.51}
# ==============
# Importance type: cover
# {'tw_N_pos_last5_mean': 98.17, 'tw_N_last5_mean': 97.7, 'tw_RelDiffPosNeg_sum_last5_mean': 97.48, 'tw_pos_sum_last5_mean': 94.29, 'tw_Retweet_Count_sum_last10_mean': 94.07, 'tw_N_pos_last10_mean': 94.0, 'tw_Like_Count_sum_last10_mean': 93.34, 'tw_N_last10_mean': 92.74, 'tw_comp_sum_last10_std': 92.32, 'tw_neg_sum_last10_mean': 90.94, 'tw_RelDiffPosNeg_sum_last10_mean': 90.74, 'Close_last2_mean': 90.21, 'tw_Like_Count_sum_last5_mean': 89.16, 'tw_RelDiffPosNeg_sum_last10_std': 89.01, 'tw_Retweet_Count_sum_last5_mean': 87.03, 'tw_N_neg_last5_mean': 86.57, 'Close_last3_mean': 86.13, 'elonmusk': 83.5, 'tw_comp_sum_last10_mean': 82.26, 'tw_comp_q3_count': 79.55, 'tw_N_pos_last10_std': 78.35, 'tw_pos_sum_last10_mean': 78.24, 'tw_Like_Count_sum_last10_std': 78.02, 'tw_N_pos': 75.0, 'tw_Retweet_Count_sum_last10_std': 73.06, 'tw_Quote_Count_sum_last10_mean': 72.46, 'tw_RelDiffPosNeg_sum': 72.3, 'tw_N_last10_std': 71.62, 'tw_N': 71.09, 'tw_comp_sum_last5_mean': 69.73, 'tw_N_neg_last10_mean': 69.42, 'tw_comp_q4_count': 68.13, 'tw_Retweet_Count_sum_last5_std': 67.45, 'tw_Reply_Count_sum_last10_std': 67.44, 'tw_Quote_Count_sum_last10_std': 66.76, 'tw_comp_q2_count': 66.58, 'Close_diff_last5': 65.41, 'tw_Reply_Count_sum_last5_std': 64.83, 'Close_last5_mean': 63.41, 'Close_last7_mean': 61.87, 'tw_N_neg_last10_std': 60.42, 'tw_Retweet_Count_sum': 58.93, 'tw_comp_q1_count': 58.05, 'Close_diff_last7': 57.49, 'tw_Like_Count_sum': 57.41, 'tw_pos_sum_last10_std': 56.07, 'tw_comp_q5_count': 55.45, 'tw_Retweet_Count_mean': 54.47, 'tw_Like_Count_mean': 54.43, 'tw_N_neg': 54.16, 'tw_neg_sum_last5_mean': 53.42, 'Close': 52.23, 'tw_Quote_Count_sum_last5_std': 51.6, 'tw_N_neg_last5_std': 51.39, 'tw_Quote_Count_sum_last5_mean': 51.0, 'tw_Reply_Count_sum': 50.97, 'tw_Reply_Count_sum_last10_mean': 49.69, 'Close_diff_last7_rel': 46.72, 'tw_N_pos_last5_std': 45.73, 'Close_diff_last3': 45.06, 'tw_Quote_Count_sum': 45.02, 'tw_topic3_freq': 44.9, 'tw_Like_Count_std': 44.52, 'tw_Like_Count_sum_last5_std': 44.44, 'tw_Quote_Count_std': 43.13, 'tw_neg_sum_last10_std': 42.61, 'Close_diff_last2': 42.36, 'tw_Reply_Count_sum_last5_mean': 41.25, 'tw_RelDiffPosNeg_sum_last5_std': 41.03, 'tw_topic1_freq': 40.55, 'tw_RelDiffPosNeg_std': 40.05, 'tw_comp_sum': 39.71, 'tw_RelDiffPosNeg_mean': 39.47, 'Close_diff_last2_rel': 39.09, 'tw_neg_sum': 38.34, 'Close_diff_last1': 37.46, 'Close_diff_last1_rel': 37.37, 'tw_comp_mean': 36.41, 'tw_N_last5_std': 36.31, 'tw_Reply_Count_mean': 36.09, 'tw_topic2_freq': 36.05, 'tw_pos_mean': 35.64, 'tw_Reply_Count_std': 35.55, 'tw_neg_sum_last5_std': 34.27, 'tw_Retweet_Count_std': 32.8, 'tw_neg_std': 31.84, 'Close_diff_last5_rel': 31.26, 'tw_Quote_Count_mean': 29.75, 'tw_pos_std': 29.32, 'tw_pos_sum_last5_std': 28.58, 'Close_last2_std': 28.12, 'tw_comp_sum_last5_std': 27.8, 'tw_comp_std': 27.11, 'tw_neg_mean': 26.03, 'Close_diff_last3_rel': 25.77, 'Close_last7_std': 24.34, 'Close_last3_std': 23.66, 'tw_pos_sum': 23.51, 'Close_last5_std': 20.36}

# %% [markdown]
# ## Target: Absolute difference to the next day's BTC Close price

# %% [markdown]
# ### Prepare training and testing datasets

# %%
# Define target and input variables
target = 'Close_diff_next1'
variables = df_ana.columns.to_list()

# Split
y = df_ana[target]
X = df_ana[variables]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Remove all variables derived from the BTC Close price
skip_pattern = 'next'

X_train_tmp = X_train[X_train.columns.drop(list(X_train.filter(like=skip_pattern)))].copy(deep=True)
X_train_tmp.drop(columns=['Date'], inplace=True)

X_test_tmp = X_test[X_test.columns.drop(list(X_test.filter(like=skip_pattern)))].copy(deep=True)
X_test_tmp.drop(columns=['Date'], inplace=True)

# %% [markdown]
# ### Prepare and train the model

# %%
model = xgb.XGBRegressor(n_estimators = 1000,\
                        learning_rate = 0.01,\
                        max_depth = 5,\
                        min_split_loss = 10,\
                        min_child_weight = 1,\
                        colsample_bytree = 0.7,\
                        subsample = 0.5,\
                        reg_lambda = 2,\
                        reg_alpha = 0)

#model.fit(X_train_tmp.drop(columns=['Date']),y_train)
model.fit(X_train_tmp,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=10, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=5,
#              min_child_weight=1, min_split_loss=10, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=4,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=2,
#              scale_pos_weight=1, subsample=0.5, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %% [markdown]
# ### Compute extra features for performance evaluation

# %%
y_pred=model.predict(X_test_tmp)

X_test['Pred_diff_next1'] = list(y_pred)
X_test['Pred_diff_next1_rel'] = (X_test.Pred_diff_next1/X_test.Close).to_list()
X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1)
# Out:
# <ipython-input-16-b6d71e7a9ad9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1'] = list(y_pred)
# <ipython-input-16-b6d71e7a9ad9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_rel'] = (X_test.Pred_diff_next1/X_test.Close).to_list()
# <ipython-input-16-b6d71e7a9ad9>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1)

# %% [markdown]
# ### Performance evaluation

# %%
print('==================================================================================')
print('Performance on the absolute diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1']
pred = X_test['Pred_diff_next1']
print('+++ Diff to next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the relative diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_rel']
pred = X_test['Pred_diff_next1_rel']
print('+++ Relative diff to next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the signed diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_sgn']
pred = X_test['Pred_diff_next1_sgn']
print('+++ Next day BTC price')
print(f"Accuracy:    {accuracy_score(test, pred)}")
# Out:
# ==================================================================================
# Performance on the absolute diff between today's and next day's BTC Close price
# +++ Diff to next day BTC price
# Explained variance:    -0.056155505006995066
# R2:                    -0.06953510420812004
# MAE:                   515.4794459999537
# MSE:                   855158.8638420582
#
# ==================================================================================
# Performance on the relative diff between today's and next day's BTC Close price
# +++ Relative diff to next day BTC price
# Explained variance:    -0.14108042343444915
# R2:                    -967.5963979332623
# MAE:                   0.9985243097509701
# MSE:                   0.9982267844420525
#
# ==================================================================================
# Performance on the signed diff between today's and next day's BTC Close price
# +++ Next day BTC price
# Accuracy:    0.5074626865671642

# %%
import operator

for importance_type in ['weight', 'gain', 'cover']:

    # Get the importance dictionary (by gain) from the booster
    importance = model.get_booster().get_score(importance_type=importance_type)

    # make your changes
    for key in importance.keys():
        importance[key] = round(importance[key],2)
        
    print('==============')
    print(f'Importance type: {importance_type}')
    print(dict(sorted(importance.items(),
                            key=operator.itemgetter(1),
                            reverse=True)))

    # provide the importance dictionary to the plotting function
    #ax = plot_importance(importance, max_num_features=3, importance_type='gain', show_values=True)

    # Plot variable importance
    ax = xgb.plot_importance(importance, max_num_features=10, grid=False, xlabel=None,\
                             title='Feature importance according to '+importance_type)
    fig = ax.figure
    fig.set_size_inches(10, 10)
# Out:
# ==============
# Importance type: weight
# {'Close': 1432, 'Close_last7_mean': 712, 'Close_last7_std': 539, 'Close_diff_last1': 412, 'Close_last5_std': 350, 'Close_last2_std': 311, 'Close_diff_last7': 299, 'Close_last3_std': 285, 'Close_last5_mean': 275, 'Close_diff_last5': 253, 'Close_diff_last2': 227, 'Close_diff_last3': 220, 'tw_Retweet_Count_sum_last5_std': 219, 'tw_RelDiffPosNeg_std': 214, 'tw_pos_mean': 209, 'tw_Retweet_Count_mean': 203, 'Close_diff_last1_rel': 200, 'tw_pos_std': 195, 'tw_comp_std': 189, 'tw_neg_mean': 188, 'tw_neg_std': 185, 'tw_neg_sum': 164, 'tw_Reply_Count_mean': 162, 'tw_Quote_Count_sum_last5_std': 160, 'tw_neg_sum_last10_mean': 159, 'tw_topic1_freq': 153, 'Close_diff_last7_rel': 153, 'tw_Reply_Count_sum_last5_mean': 153, 'tw_Like_Count_mean': 152, 'Close_diff_last3_rel': 142, 'tw_Like_Count_std': 141, 'tw_topic2_freq': 137, 'tw_Quote_Count_sum_last10_std': 128, 'tw_RelDiffPosNeg_mean': 127, 'Close_last3_mean': 126, 'tw_Quote_Count_std': 122, 'Close_diff_last5_rel': 120, 'tw_Like_Count_sum_last10_std': 120, 'tw_comp_sum': 120, 'tw_topic3_freq': 119, 'tw_Retweet_Count_sum_last10_std': 116, 'tw_comp_mean': 116, 'Close_last2_mean': 114, 'tw_Quote_Count_mean': 109, 'tw_Reply_Count_sum': 107, 'tw_RelDiffPosNeg_sum_last10_std': 106, 'Close_diff_last2_rel': 106, 'tw_Reply_Count_std': 106, 'tw_Reply_Count_sum_last5_std': 105, 'tw_neg_sum_last5_std': 105, 'tw_neg_sum_last5_mean': 101, 'tw_pos_sum_last5_std': 100, 'tw_comp_sum_last10_std': 100, 'tw_RelDiffPosNeg_sum_last5_std': 98, 'tw_Retweet_Count_std': 94, 'tw_Like_Count_sum_last5_std': 93, 'tw_comp_q4_count': 93, 'tw_neg_sum_last10_std': 91, 'tw_RelDiffPosNeg_sum': 89, 'tw_N_neg_last10_std': 86, 'tw_Like_Count_sum_last5_mean': 83, 'tw_Quote_Count_sum_last10_mean': 82, 'tw_pos_sum_last10_std': 81, 'tw_Reply_Count_sum_last10_std': 79, 'tw_N_neg': 78, 'tw_comp_q3_count': 77, 'tw_Retweet_Count_sum': 76, 'tw_pos_sum': 76, 'tw_comp_q5_count': 73, 'tw_Reply_Count_sum_last10_mean': 70, 'tw_comp_sum_last5_std': 70, 'tw_Retweet_Count_sum_last5_mean': 67, 'tw_Quote_Count_sum': 66, 'tw_comp_sum_last10_mean': 61, 'tw_N_last5_std': 61, 'tw_Quote_Count_sum_last5_mean': 60, 'tw_Like_Count_sum_last10_mean': 59, 'tw_N_neg_last5_std': 59, 'tw_Like_Count_sum': 58, 'tw_comp_q1_count': 57, 'tw_pos_sum_last5_mean': 56, 'tw_N_neg_last10_mean': 54, 'tw_comp_sum_last5_mean': 53, 'tw_N_neg_last5_mean': 52, 'tw_N_pos_last5_std': 51, 'tw_Retweet_Count_sum_last10_mean': 49, 'tw_N_last10_std': 48, 'tw_RelDiffPosNeg_sum_last5_mean': 44, 'tw_pos_sum_last10_mean': 43, 'tw_N_last10_mean': 41, 'tw_comp_q2_count': 39, 'tw_RelDiffPosNeg_sum_last10_mean': 34, 'tw_N': 29, 'tw_N_last5_mean': 26, 'tw_N_pos': 24, 'tw_N_pos_last10_std': 20, 'tw_N_pos_last5_mean': 19, 'tw_N_pos_last10_mean': 15, 'elonmusk': 1}
# ==============
# Importance type: gain
# {'tw_comp_q4_count': 5315172.87, 'tw_Reply_Count_sum_last10_mean': 3888536.08, 'tw_N_neg_last5_mean': 3314792.87, 'tw_neg_sum_last10_mean': 3282538.52, 'tw_Retweet_Count_sum_last10_mean': 3148037.45, 'tw_Like_Count_sum_last10_std': 3065712.37, 'tw_N_neg': 2922698.49, 'tw_N_last10_mean': 2917266.64, 'tw_RelDiffPosNeg_sum': 2882060.22, 'tw_Retweet_Count_sum_last10_std': 2839922.04, 'tw_pos_sum_last10_mean': 2784568.35, 'tw_comp_q2_count': 2784219.94, 'tw_N_last5_mean': 2771966.43, 'tw_neg_sum_last5_mean': 2729639.0, 'tw_N_pos_last5_mean': 2611140.49, 'tw_Like_Count_sum_last5_mean': 2511845.84, 'tw_N_pos_last10_std': 2484987.39, 'tw_Retweet_Count_sum_last5_mean': 2483463.84, 'tw_Like_Count_sum_last5_std': 2406213.82, 'tw_RelDiffPosNeg_sum_last10_mean': 2378787.99, 'tw_Reply_Count_sum_last10_std': 2360317.6, 'tw_N_neg_last10_mean': 2337108.59, 'tw_N': 2248005.59, 'tw_RelDiffPosNeg_sum_last10_std': 2133752.92, 'tw_N_pos': 2122687.68, 'tw_comp_q1_count': 2081727.08, 'tw_N_last10_std': 2070296.15, 'tw_Like_Count_sum': 2052904.0, 'tw_comp_sum_last10_mean': 2049791.06, 'Close_diff_last7': 2023204.84, 'tw_Quote_Count_sum_last10_mean': 2022517.89, 'tw_pos_sum_last5_mean': 1986808.78, 'tw_comp_q5_count': 1963307.08, 'tw_RelDiffPosNeg_sum_last5_mean': 1906330.44, 'tw_comp_sum_last10_std': 1889533.99, 'tw_Like_Count_sum_last10_mean': 1885833.34, 'tw_Reply_Count_sum_last5_mean': 1761771.49, 'tw_pos_std': 1613713.67, 'tw_comp_mean': 1594044.27, 'Close_diff_last3': 1581159.76, 'tw_Quote_Count_sum_last5_mean': 1501128.23, 'Close_diff_last1': 1466293.42, 'tw_Retweet_Count_sum': 1448732.91, 'Close_last2_mean': 1431990.22, 'Close_diff_last1_rel': 1420776.37, 'Close_last3_mean': 1411119.75, 'tw_Retweet_Count_sum_last5_std': 1373369.92, 'tw_Quote_Count_sum_last5_std': 1361430.25, 'tw_neg_sum_last10_std': 1306797.59, 'tw_comp_q3_count': 1301689.97, 'tw_N_neg_last10_std': 1294505.08, 'tw_Quote_Count_sum_last10_std': 1286585.39, 'tw_N_neg_last5_std': 1235505.49, 'tw_comp_sum_last5_mean': 1235313.83, 'Close_diff_last7_rel': 1197170.9, 'tw_Quote_Count_mean': 1138968.89, 'tw_Retweet_Count_std': 1116807.72, 'tw_neg_sum': 1114268.85, 'tw_pos_mean': 1088106.11, 'Close_diff_last2': 1082100.34, 'tw_RelDiffPosNeg_std': 1074098.34, 'Close_last5_mean': 1074088.21, 'Close_diff_last2_rel': 1065074.45, 'tw_Quote_Count_sum': 1055104.48, 'Close_last7_mean': 1051012.44, 'Close_diff_last5': 1050992.22, 'Close_last7_std': 1041599.17, 'tw_pos_sum_last5_std': 1037822.12, 'tw_Quote_Count_std': 1030740.46, 'tw_Reply_Count_sum': 1006039.34, 'tw_Reply_Count_sum_last5_std': 991753.53, 'Close_last3_std': 973246.23, 'tw_neg_std': 950669.46, 'tw_Like_Count_std': 924662.21, 'tw_N_pos_last10_mean': 921375.74, 'tw_neg_sum_last5_std': 918677.39, 'tw_Like_Count_mean': 910624.27, 'tw_Reply_Count_mean': 907332.43, 'tw_comp_std': 901663.35, 'tw_pos_sum': 859865.56, 'tw_comp_sum': 851605.58, 'Close_last5_std': 803979.13, 'tw_N_pos_last5_std': 795472.24, 'Close_diff_last3_rel': 766191.73, 'Close_last2_std': 753794.28, 'tw_RelDiffPosNeg_sum_last5_std': 735811.06, 'tw_neg_mean': 704667.55, 'tw_RelDiffPosNeg_mean': 689097.26, 'tw_topic3_freq': 685860.36, 'Close_diff_last5_rel': 656631.45, 'tw_comp_sum_last5_std': 649144.43, 'tw_topic2_freq': 646142.3, 'tw_pos_sum_last10_std': 602912.99, 'tw_Retweet_Count_mean': 600500.04, 'tw_topic1_freq': 570384.43, 'tw_Reply_Count_std': 549383.07, 'tw_N_last5_std': 510076.54, 'Close': 494944.24, 'elonmusk': 45108.33}
# ==============
# Importance type: cover
# {'tw_N_neg_last5_mean': 103.83, 'tw_N_pos_last5_mean': 103.47, 'tw_Like_Count_sum_last5_mean': 101.95, 'tw_Retweet_Count_sum_last5_std': 101.73, 'tw_N_last5_mean': 99.08, 'tw_Retweet_Count_sum_last10_mean': 99.04, 'tw_N_pos_last10_mean': 97.6, 'tw_Like_Count_sum_last10_std': 94.71, 'tw_RelDiffPosNeg_sum_last10_mean': 92.38, 'tw_N_last10_mean': 91.34, 'tw_N_neg_last10_mean': 90.72, 'tw_neg_sum_last10_mean': 89.68, 'tw_N_neg_last10_std': 89.26, 'tw_RelDiffPosNeg_sum_last5_mean': 88.84, 'tw_Retweet_Count_sum_last10_std': 87.28, 'tw_Like_Count_sum_last10_mean': 85.76, 'tw_comp_q4_count': 85.58, 'Close_diff_last7': 84.84, 'tw_Quote_Count_sum_last10_mean': 84.44, 'tw_comp_sum_last10_std': 84.04, 'tw_RelDiffPosNeg_sum_last10_std': 82.66, 'tw_Retweet_Count_sum_last5_mean': 81.84, 'tw_N_pos_last10_std': 81.05, 'tw_Quote_Count_sum_last10_std': 77.66, 'tw_Reply_Count_sum_last10_std': 76.96, 'tw_pos_sum_last5_mean': 76.02, 'tw_Quote_Count_sum_last5_std': 74.99, 'tw_Reply_Count_sum_last5_std': 73.45, 'tw_pos_sum_last10_mean': 73.09, 'tw_comp_sum_last10_mean': 71.74, 'tw_comp_q1_count': 71.05, 'tw_RelDiffPosNeg_sum': 67.03, 'tw_comp_sum_last5_mean': 66.25, 'tw_N_last10_std': 65.52, 'Close_last3_mean': 64.98, 'tw_neg_sum_last5_mean': 63.44, 'tw_N': 62.59, 'tw_N_neg': 61.9, 'tw_N_pos': 60.33, 'tw_Retweet_Count_mean': 60.26, 'tw_neg_sum_last10_std': 59.13, 'tw_comp_q2_count': 59.03, 'tw_Reply_Count_sum_last10_mean': 58.87, 'tw_Quote_Count_sum_last5_mean': 58.53, 'tw_Like_Count_mean': 58.18, 'tw_N_pos_last5_std': 57.75, 'Close_diff_last5': 57.15, 'tw_comp_q5_count': 56.86, 'tw_N_neg_last5_std': 56.22, 'tw_Reply_Count_sum_last5_mean': 55.11, 'Close_diff_last7_rel': 54.12, 'Close_diff_last1': 53.76, 'tw_Like_Count_sum_last5_std': 53.76, 'tw_RelDiffPosNeg_sum_last5_std': 53.41, 'tw_Like_Count_sum': 51.66, 'Close_diff_last3': 51.57, 'tw_Like_Count_std': 50.61, 'Close_last2_mean': 50.58, 'tw_Quote_Count_std': 50.48, 'tw_comp_q3_count': 49.78, 'tw_Retweet_Count_sum': 49.71, 'tw_pos_sum_last10_std': 49.57, 'tw_Reply_Count_mean': 49.06, 'tw_topic1_freq': 48.24, 'tw_RelDiffPosNeg_mean': 47.87, 'tw_topic3_freq': 44.73, 'tw_topic2_freq': 43.68, 'tw_RelDiffPosNeg_std': 42.84, 'Close_last5_mean': 42.79, 'tw_Reply_Count_std': 41.78, 'Close_diff_last3_rel': 41.77, 'tw_comp_sum_last5_std': 41.07, 'Close_diff_last5_rel': 40.73, 'tw_Reply_Count_sum': 40.45, 'tw_neg_sum_last5_std': 39.42, 'tw_comp_mean': 37.78, 'tw_N_last5_std': 36.79, 'Close_diff_last2': 34.99, 'tw_neg_std': 34.86, 'tw_pos_mean': 34.7, 'tw_Quote_Count_sum': 34.7, 'tw_Quote_Count_mean': 33.72, 'tw_Retweet_Count_std': 33.55, 'Close_diff_last1_rel': 33.41, 'Close_diff_last2_rel': 31.87, 'tw_comp_sum': 31.64, 'tw_pos_sum_last5_std': 31.39, 'Close_last7_mean': 31.06, 'tw_pos_std': 29.06, 'tw_neg_sum': 28.79, 'tw_comp_std': 27.84, 'tw_neg_mean': 24.85, 'Close_last2_std': 23.45, 'Close_last7_std': 22.71, 'tw_pos_sum': 22.59, 'Close_last5_std': 20.49, 'Close_last3_std': 17.96, 'Close': 12.87, 'elonmusk': 11.0}

# %% [markdown]
# ## Target: Relative difference to the next day's BTC Close price

# %% [markdown]
# ### Prepare training and testing datasets

# %%
# Define target and input variables
target = 'Close_diff_next1_rel'
variables = df_ana.columns.to_list()

# Split
y = df_ana[target]
X = df_ana[variables]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Remove all variables derived from the BTC Close price
skip_pattern = 'nrxt'

X_train_tmp = X_train[X_train.columns.drop(list(X_train.filter(like=skip_pattern)))].copy(deep=True)
X_train_tmp.drop(columns=['Date'], inplace=True)

X_test_tmp = X_test[X_test.columns.drop(list(X_test.filter(like=skip_pattern)))].copy(deep=True)
X_test_tmp.drop(columns=['Date'], inplace=True)

# %% [markdown]
# ### Prepare and train the model

# %%
model = xgb.XGBRegressor(n_estimators = 1000,\
                        learning_rate = 0.01,\
                        max_depth = 5,\
                        min_split_loss = 10,\
                        min_child_weight = 1,\
                        colsample_bytree = 0.7,\
                        subsample = 0.5,\
                        reg_lambda = 2,\
                        reg_alpha = 0)

#model.fit(X_train_tmp.drop(columns=['Date']),y_train)
model.fit(X_train_tmp,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=10, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=5,
#              min_child_weight=1, min_split_loss=10, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=4,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=2,
#              scale_pos_weight=1, subsample=0.5, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %% [markdown]
# ### Compute extra features for performance evaluation

# %%
y_pred=model.predict(X_test_tmp)

X_test['Pred_diff_next1'] = list(y_pred)
X_test['Pred_diff_next1_rel'] = list(y_pred)
X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1_rel)
# Out:
# <ipython-input-21-86142636e4f0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1'] = list(y_pred)
# <ipython-input-21-86142636e4f0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_rel'] = list(y_pred)
# <ipython-input-21-86142636e4f0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Pred_diff_next1_sgn'] = np.sign(X_test.Pred_diff_next1_rel)

# %% [markdown]
# ### Performance evaluation

# %%
print('==================================================================================')
print('Performance on the relative diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_rel']
pred = X_test['Pred_diff_next1_rel']
print('+++ Relative diff to next day BTC price')
print(f"Explained variance:    {explained_variance_score(test, pred)}")
print(f"R2:                    {r2_score(test, pred)}")
print(f"MAE:                   {mean_absolute_error(test, pred)}")
print(f"MSE:                   {mean_squared_error(test, pred)}")
print()

print('==================================================================================')
print('Performance on the signed diff between today\'s and next day\'s BTC Close price' )
test = X_test['Close_diff_next1_sgn']
pred = X_test['Pred_diff_next1_sgn']
print('+++ Next day BTC price')
print(f"Accuracy:    {accuracy_score(test, pred)}")
# Out:
# ==================================================================================
# Performance on the relative diff between today's and next day's BTC Close price
# +++ Relative diff to next day BTC price
# Explained variance:    2.220446049250313e-16
# R2:                    -0.01599615010776767
# MAE:                   0.021703514819490833
# MSE:                   0.001047076545082776
#
# ==================================================================================
# Performance on the signed diff between today's and next day's BTC Close price
# +++ Next day BTC price
# Accuracy:    0.5671641791044776

# %% [markdown]
# ## Target: Signed difference to the next day's BTC Close price

# %% [markdown]
# ### Prepare training and testing datasets

# %%
# Define target and input variables
target = 'Close_diff_next1_sgn'
variables = df_ana.columns.to_list()

# Split
y = df_ana[target]
X = df_ana[variables]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
#X_test.sort_values(by=['Date'], inplace=True)

# Remove all variables derived from the BTC Close price
skip_pattern = 'next'

X_train_tmp = X_train[X_train.columns.drop(list(X_train.filter(like=skip_pattern)))].copy(deep=True)
X_train_tmp.drop(columns=['Date'], inplace=True)

X_test_tmp = X_test[X_test.columns.drop(list(X_test.filter(like=skip_pattern)))].copy(deep=True)
X_test_tmp.drop(columns=['Date'], inplace=True)

# %% [markdown]
# ### Prepare and train the model

# %%
imbalance = len(y_train)/sum(y_train)

xgb_model = xgb.XGBClassifier(objective="binary:logistic", n_estimators=20,\
                              random_state=42, eval_metric=["auc"],\
                             #scale_pos_weight=imbalance
                             )
#eval_metric=["auc", "error", "error@0.6"]

#xgb_model.fit(X_train, y_train, eval_set=[(X_test, y_test)])
xgb_model.fit(X_train_tmp, y_train)

y_pred = xgb_model.predict(X_test_tmp)
# Out:
# /Users/snezana/testenv/lib/python3.9/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %% [markdown]
# ### Performance evaluation

# %%
from sklearn.metrics import classification_report,confusion_matrix

print('==================================================================================')
print('Performance on the signed diff between today\'s and next day\'s BTC Close price' )
print()
print('Accuracy:')
print(accuracy_score(y_test,y_pred))
print()
print('Confusion matrix:')
print(confusion_matrix(y_test,y_pred))
print()
print('Classification report:')
print(classification_report(y_test,y_pred))
# Out:
# ==================================================================================
# Performance on the signed diff between today's and next day's BTC Close price
#
# Accuracy:
# 0.582089552238806
#
# Confusion matrix:
# [[11 18]
#  [10 28]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#         -1.0       0.52      0.38      0.44        29
#          1.0       0.61      0.74      0.67        38
#
#     accuracy                           0.58        67
#    macro avg       0.57      0.56      0.55        67
# weighted avg       0.57      0.58      0.57        67
